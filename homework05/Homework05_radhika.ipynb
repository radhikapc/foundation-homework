# %%
import requests

# %%
Lil_response = requests.get('https://api.spotify.com/v1/search?query=Lil&type=artist&limit=50&country=US')
Lil_data = Lil_response.json()
Lil_data
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Lil&offset=0&limit=50&type=artist',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55Aa2cqylxrFIXC767Z865'},
#     'followers': {'href': None, 'total': 2623705},
#     'genres': ['dirty south rap', 'pop rap', 'southern hip hop', 'trap music'],
#     'href': 'https://api.spotify.com/v1/artists/55Aa2cqylxrFIXC767Z865',
#     'id': '55Aa2cqylxrFIXC767Z865',
#     'images': [{'height': 1239,
#       'url': 'https://i.scdn.co/image/cf012139c3b8681b46a66bae70558a8a336ab231',
#       'width': 1000},
#      {'height': 793,
#       'url': 'https://i.scdn.co/image/fffd48d60e27901f6e9ce99423f045cb2b893944',
#       'width': 640},
#      {'height': 248,
#       'url': 'https://i.scdn.co/image/bf03141629c202e94b206f1374a39326a9d8c6ca',
#       'width': 200},
#      {'height': 79,
#       'url': 'https://i.scdn.co/image/521f99f2469883b8806a69a3a2487fdd983bd621',
#       'width': 64}],
#     'name': 'Lil Wayne',
#     'popularity': 86,
#     'type': 'artist',
#     'uri': 'spotify:artist:55Aa2cqylxrFIXC767Z865'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6icQOAFXDZKsumw3YXyusw'},
#     'followers': {'href': None, 'total': 37877},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6icQOAFXDZKsumw3YXyusw',
#     'id': '6icQOAFXDZKsumw3YXyusw',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/add25baa69fc7bfd9cfd5d87716941028c2d6736',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/3f8205117bdd028a648ad3fc925f9fb46dfa26fa',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ccc54e2911dbc5463acb401ee61489e27d991408',
#       'width': 64}],
#     'name': 'Lil Yachty',
#     'popularity': 72,
#     'type': 'artist',
#     'uri': 'spotify:artist:6icQOAFXDZKsumw3YXyusw'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4O15NlyKLIASxsJ0PrXPfz'},
#     'followers': {'href': None, 'total': 54986},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4O15NlyKLIASxsJ0PrXPfz',
#     'id': '4O15NlyKLIASxsJ0PrXPfz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/8c02344d1cb9069a5a2a9d1e860dc88b04088549',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/28ac78387ad26048ccab0b671cbaddb30a2b52da',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/6b074e198860470024e57ebbc1dda9f58088c506',
#       'width': 160}],
#     'name': 'Lil Uzi Vert',
#     'popularity': 72,
#     'type': 'artist',
#     'uri': 'spotify:artist:4O15NlyKLIASxsJ0PrXPfz'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1tqhsYv8yBBdwANFNzHtcr'},
#     'followers': {'href': None, 'total': 224686},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1tqhsYv8yBBdwANFNzHtcr',
#     'id': '1tqhsYv8yBBdwANFNzHtcr',
#     'images': [{'height': 1000,
#       'url': 'https://i.scdn.co/image/a9c000526b14038b1fe69c72b0775f125bdf08af',
#       'width': 1000},
#      {'height': 640,
#       'url': 'https://i.scdn.co/image/31eac6ae8bdd6909236b5fd729d17406cc794e2d',
#       'width': 640},
#      {'height': 200,
#       'url': 'https://i.scdn.co/image/24dcb67ddd3afc794a4b1dab4cc1a47035a0beab',
#       'width': 200},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/2d2ebd85f676535129dbb7c3a4bb96e7bfd940a7',
#       'width': 64}],
#     'name': 'Lil Dicky',
#     'popularity': 68,
#     'type': 'artist',
#     'uri': 'spotify:artist:1tqhsYv8yBBdwANFNzHtcr'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6z7xFFHxYkE9t8bwIF0Bvg'},
#     'followers': {'href': None, 'total': 220122},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6z7xFFHxYkE9t8bwIF0Bvg',
#     'id': '6z7xFFHxYkE9t8bwIF0Bvg',
#     'images': [{'height': 667,
#       'url': 'https://i.scdn.co/image/f89376b78fe94a1692a5768f8f3440a4397bfb17',
#       'width': 1000},
#      {'height': 427,
#       'url': 'https://i.scdn.co/image/fbf5353d4410a540cc74285d387d9e59d038592a',
#       'width': 640},
#      {'height': 133,
#       'url': 'https://i.scdn.co/image/39995515de01dc9eb91bc9c17d5c1921e7e54a1f',
#       'width': 200},
#      {'height': 43,
#       'url': 'https://i.scdn.co/image/b34f525381a78c72f423d74b76a47e1a1da9f7f8',
#       'width': 64}],
#     'name': 'Boosie Badazz',
#     'popularity': 67,
#     'type': 'artist',
#     'uri': 'spotify:artist:6z7xFFHxYkE9t8bwIF0Bvg'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7sfl4Xt5KmfyDs2T3SVSMK'},
#     'followers': {'href': None, 'total': 256024},
#     'genres': ['crunk', 'dirty south rap', 'southern hip hop'],
#     'href': 'https://api.spotify.com/v1/artists/7sfl4Xt5KmfyDs2T3SVSMK',
#     'id': '7sfl4Xt5KmfyDs2T3SVSMK',
#     'images': [{'height': 664,
#       'url': 'https://i.scdn.co/image/885941564eadf27b7ee86d089e87967f9e3cf612',
#       'width': 1000},
#      {'height': 425,
#       'url': 'https://i.scdn.co/image/b5495566665b41f3dc2560d37d043e4a3dc2ca41',
#       'width': 640},
#      {'height': 133,
#       'url': 'https://i.scdn.co/image/6ea9f92a43e23eaa7ced98d8773de37229b1410d',
#       'width': 200},
#      {'height': 43,
#       'url': 'https://i.scdn.co/image/ddef386b560619f296a27059874ad3fc7fd5d85d',
#       'width': 64}],
#     'name': 'Lil Jon',
#     'popularity': 72,
#     'type': 'artist',
#     'uri': 'spotify:artist:7sfl4Xt5KmfyDs2T3SVSMK'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6L3x3if9RVimruryD9LoFb'},
#     'followers': {'href': None, 'total': 64182},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6L3x3if9RVimruryD9LoFb',
#     'id': '6L3x3if9RVimruryD9LoFb',
#     'images': [{'height': 879,
#       'url': 'https://i.scdn.co/image/8942e9c0745697fa8e3e75f02aa461d722a0519d',
#       'width': 587},
#      {'height': 299,
#       'url': 'https://i.scdn.co/image/9fa49263a60cd27888e23b6c6c10c930af48114e',
#       'width': 200},
#      {'height': 96,
#       'url': 'https://i.scdn.co/image/c11e5e1e9d21cee430c1bd7c72e387422854bd6a',
#       'width': 64}],
#     'name': 'King Lil G',
#     'popularity': 61,
#     'type': 'artist',
#     'uri': 'spotify:artist:6L3x3if9RVimruryD9LoFb'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3hcs9uc56yIGFCSy9leWe7'},
#     'followers': {'href': None, 'total': 134060},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3hcs9uc56yIGFCSy9leWe7',
#     'id': '3hcs9uc56yIGFCSy9leWe7',
#     'images': [{'height': 426,
#       'url': 'https://i.scdn.co/image/2b83f7df57f9098558c63047c494dea26f2da67e',
#       'width': 999},
#      {'height': 273,
#       'url': 'https://i.scdn.co/image/42e0d88103ed677b9a6cfa426e53428127ae903d',
#       'width': 640},
#      {'height': 85,
#       'url': 'https://i.scdn.co/image/b127461c288b3777fd18ffcd3523856b6063ea1e',
#       'width': 199},
#      {'height': 27,
#       'url': 'https://i.scdn.co/image/3674b105e3a72fbb92794029846a43dc66b2fcab',
#       'width': 63}],
#     'name': 'Lil Durk',
#     'popularity': 60,
#     'type': 'artist',
#     'uri': 'spotify:artist:3hcs9uc56yIGFCSy9leWe7'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3ciRvbBIVz9fBoPbtSYq4x'},
#     'followers': {'href': None, 'total': 17043},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3ciRvbBIVz9fBoPbtSYq4x',
#     'id': '3ciRvbBIVz9fBoPbtSYq4x',
#     'images': [{'height': 500,
#       'url': 'https://i.scdn.co/image/aafc4156598fa9f8f052ec5687e648ba9120f07e',
#       'width': 554},
#      {'height': 181,
#       'url': 'https://i.scdn.co/image/7a9ccdaebabf83f763af6664d5d483c57332bc08',
#       'width': 200},
#      {'height': 58,
#       'url': 'https://i.scdn.co/image/e74083480033e85373d3deb546f16d8beedeccb3',
#       'width': 64}],
#     'name': 'Lil Jon & The East Side Boyz',
#     'popularity': 60,
#     'type': 'artist',
#     'uri': 'spotify:artist:3ciRvbBIVz9fBoPbtSYq4x'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4uSN8Y3kgFNVULUWsZEAVW'},
#     'followers': {'href': None, 'total': 44098},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4uSN8Y3kgFNVULUWsZEAVW',
#     'id': '4uSN8Y3kgFNVULUWsZEAVW',
#     'images': [{'height': 1000,
#       'url': 'https://i.scdn.co/image/07c75abe717a9b704083ef38c4446abbff10fda5',
#       'width': 1000},
#      {'height': 640,
#       'url': 'https://i.scdn.co/image/1903fd19c7279418c71da62aa02ce47cccf63e52',
#       'width': 640},
#      {'height': 200,
#       'url': 'https://i.scdn.co/image/9c37f8c40ab3594de42f1861f592f558f91d0f51',
#       'width': 200},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/efba595d34603b014b125d65f7851103185158b4',
#       'width': 64}],
#     'name': 'Lil Bibby',
#     'popularity': 54,
#     'type': 'artist',
#     'uri': 'spotify:artist:4uSN8Y3kgFNVULUWsZEAVW'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5QdEbQJ3ylBnc3gsIASAT5'},
#     'followers': {'href': None, 'total': 51466},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5QdEbQJ3ylBnc3gsIASAT5',
#     'id': '5QdEbQJ3ylBnc3gsIASAT5',
#     'images': [{'height': 667,
#       'url': 'https://i.scdn.co/image/2cb955d0b6d08e1ff70cff98b332f6debf7a8e4a',
#       'width': 1000},
#      {'height': 427,
#       'url': 'https://i.scdn.co/image/72667af5dfd57266ba7348bbec97c246986bdbfe',
#       'width': 640},
#      {'height': 133,
#       'url': 'https://i.scdn.co/image/f366a759361f875f6259ef805c76e39ff3dd754c',
#       'width': 199},
#      {'height': 43,
#       'url': 'https://i.scdn.co/image/d7b0cd61112a7b8b6326c6454652685c1d1baa1c',
#       'width': 64}],
#     'name': 'G Herbo',
#     'popularity': 53,
#     'type': 'artist',
#     'uri': 'spotify:artist:5QdEbQJ3ylBnc3gsIASAT5'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7B7TGqQe7QTVm2U6q8jzk1'},
#     'followers': {'href': None, 'total': 35824},
#     'genres': ['chicano rap', 'latin hip hop'],
#     'href': 'https://api.spotify.com/v1/artists/7B7TGqQe7QTVm2U6q8jzk1',
#     'id': '7B7TGqQe7QTVm2U6q8jzk1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/7b37dc3ed21b4236502d24a897ac02aa4eb9f183',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/457e18474f5cf18eae93e1435dcc5d2fb88c8efd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/8e7c25760b9b5d6dbc58ebc30443114fdfdfb927',
#       'width': 64}],
#     'name': 'Lil Rob',
#     'popularity': 50,
#     'type': 'artist',
#     'uri': 'spotify:artist:7B7TGqQe7QTVm2U6q8jzk1'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1bPxKZtCdjB1aj1csBJpdS'},
#     'followers': {'href': None, 'total': 23836},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1bPxKZtCdjB1aj1csBJpdS',
#     'id': '1bPxKZtCdjB1aj1csBJpdS',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/c3f33bf2d8bc3e00d0d82fd9e2a11c0594079833',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/6535600354e3ff225b5704ab3c9b4a4033746fb1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ba89cf9b97304f9f07132e8bb06293170109b64b',
#       'width': 64}],
#     'name': 'Lil Reese',
#     'popularity': 50,
#     'type': 'artist',
#     'uri': 'spotify:artist:1bPxKZtCdjB1aj1csBJpdS'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1grI9x4Uzos1Asx8JmRW6T'},
#     'followers': {'href': None, 'total': 18746},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1grI9x4Uzos1Asx8JmRW6T',
#     'id': '1grI9x4Uzos1Asx8JmRW6T',
#     'images': [{'height': 1024,
#       'url': 'https://i.scdn.co/image/3e53d37d29794eccb5fc9744b962df8f2c2b1725',
#       'width': 680},
#      {'height': 964,
#       'url': 'https://i.scdn.co/image/82bb674230d0b08e5c82e10dfe175759581e7800',
#       'width': 640},
#      {'height': 301,
#       'url': 'https://i.scdn.co/image/6f26c9f3aee5c6243f2abe210ab09446df90276b',
#       'width': 200},
#      {'height': 96,
#       'url': 'https://i.scdn.co/image/35fd540d7448475f46e06bc0b46f2ca106899910',
#       'width': 64}],
#     'name': 'Lil Keke',
#     'popularity': 48,
#     'type': 'artist',
#     'uri': 'spotify:artist:1grI9x4Uzos1Asx8JmRW6T'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7352aRY2mqSxBZwzUb6LmA'},
#     'followers': {'href': None, 'total': 118536},
#     'genres': ['hip pop', 'pop rap'],
#     'href': 'https://api.spotify.com/v1/artists/7352aRY2mqSxBZwzUb6LmA',
#     'id': '7352aRY2mqSxBZwzUb6LmA',
#     'images': [{'height': 1500,
#       'url': 'https://i.scdn.co/image/bbc23f477201e3784b54516ef2ad548794947277',
#       'width': 1000},
#      {'height': 960,
#       'url': 'https://i.scdn.co/image/4014b68d6e33d16883c70aab0972087d38e8896d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/5d3a1e94fb0fe5cf2dfb600cd7e55e8213025968',
#       'width': 200},
#      {'height': 96,
#       'url': 'https://i.scdn.co/image/6799537642674ef52cf0064aaef74cf04202c301',
#       'width': 64}],
#     'name': 'Bow Wow',
#     'popularity': 57,
#     'type': 'artist',
#     'uri': 'spotify:artist:7352aRY2mqSxBZwzUb6LmA'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5einkgXXrjhfYCyac1FANB'},
#     'followers': {'href': None, 'total': 27073},
#     'genres': ['crunk', 'dirty south rap', 'southern hip hop', 'trap music'],
#     'href': 'https://api.spotify.com/v1/artists/5einkgXXrjhfYCyac1FANB',
#     'id': '5einkgXXrjhfYCyac1FANB',
#     'images': [{'height': 300,
#       'url': 'https://i.scdn.co/image/722a084be153a03ca1bfb0c1e7c83bd4d37db156',
#       'width': 225},
#      {'height': 267,
#       'url': 'https://i.scdn.co/image/9c68dc0bb9b147bd31cb13a7b1e1d95acf481a90',
#       'width': 200},
#      {'height': 85,
#       'url': 'https://i.scdn.co/image/96df8040ad3c03f9471139786c4ea60f3998ca81',
#       'width': 64}],
#     'name': 'Lil Scrappy',
#     'popularity': 48,
#     'type': 'artist',
#     'uri': 'spotify:artist:5einkgXXrjhfYCyac1FANB'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/21O7WwRkik43ErKppxDKJq'},
#     'followers': {'href': None, 'total': 31101},
#     'genres': ['juggalo'],
#     'href': 'https://api.spotify.com/v1/artists/21O7WwRkik43ErKppxDKJq',
#     'id': '21O7WwRkik43ErKppxDKJq',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/01140761147a97db6a100c4456b531fb2d5aad82',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/0925d6476f14719b5ffd005fe0091e292c95e11e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/b232b4badce8651c11907c06ed6defcfc5616854',
#       'width': 64}],
#     'name': 'Lil Wyte',
#     'popularity': 50,
#     'type': 'artist',
#     'uri': 'spotify:artist:21O7WwRkik43ErKppxDKJq'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/74nSA5FdDOuuLw7Rn5JnuP'},
#     'followers': {'href': None, 'total': 5524},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/74nSA5FdDOuuLw7Rn5JnuP',
#     'id': '74nSA5FdDOuuLw7Rn5JnuP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/fc222056c3c65e02c96c3e94847a74ba7920757e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/052a2ef46226fa25801224fd676ba4abbb7da15a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/b3a4a57f6da39a5af2b2c56479819754caa51d35',
#       'width': 64}],
#     'name': 'Lil Blood',
#     'popularity': 45,
#     'type': 'artist',
#     'uri': 'spotify:artist:74nSA5FdDOuuLw7Rn5JnuP'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/42FaEHFfyxTdZQ5W28dXnj'},
#     'followers': {'href': None, 'total': 33976},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/42FaEHFfyxTdZQ5W28dXnj',
#     'id': '42FaEHFfyxTdZQ5W28dXnj',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/89c1a0ac4f8b95c843d633493bc3657a296e3e6b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/59654d32b34cfb51000ff26fec57ab36bf1781ae',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/b3afd3776d6e3e6ed82d45b4541e8623389e347b',
#       'width': 64}],
#     'name': 'Lil Snupe',
#     'popularity': 45,
#     'type': 'artist',
#     'uri': 'spotify:artist:42FaEHFfyxTdZQ5W28dXnj'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5qK5bOC6wLtuLhG5KvU17c'},
#     'followers': {'href': None, 'total': 21107},
#     'genres': ['hip pop'],
#     'href': 'https://api.spotify.com/v1/artists/5qK5bOC6wLtuLhG5KvU17c',
#     'id': '5qK5bOC6wLtuLhG5KvU17c',
#     'images': [{'height': 750,
#       'url': 'https://i.scdn.co/image/8e33c09ff1d5d91ea47254a389c36f626775275a',
#       'width': 600},
#      {'height': 250,
#       'url': 'https://i.scdn.co/image/991889a4147550d0421dfb80621c2e161ac7e043',
#       'width': 200},
#      {'height': 80,
#       'url': 'https://i.scdn.co/image/253d651a020406eb7c264304803463badabfe8cb',
#       'width': 64}],
#     'name': 'Lil Mama',
#     'popularity': 45,
#     'type': 'artist',
#     'uri': 'spotify:artist:5qK5bOC6wLtuLhG5KvU17c'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4dqh62yIzDBmrMeBOLiP5F'},
#     'followers': {'href': None, 'total': 224},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4dqh62yIzDBmrMeBOLiP5F',
#     'id': '4dqh62yIzDBmrMeBOLiP5F',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/5fbeb835c159b8de635ef8f5c6cc002ce138aec2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/3002b77643ae099b657a5eca5f99a79ca064b2f7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/73507e320c68d9890524a15f2eca9390a9fec455',
#       'width': 64}],
#     'name': 'Lil B',
#     'popularity': 44,
#     'type': 'artist',
#     'uri': 'spotify:artist:4dqh62yIzDBmrMeBOLiP5F'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5tth2a3v0sWwV1C7bApBdX'},
#     'followers': {'href': None, 'total': 70213},
#     'genres': ['hip pop'],
#     'href': 'https://api.spotify.com/v1/artists/5tth2a3v0sWwV1C7bApBdX',
#     'id': '5tth2a3v0sWwV1C7bApBdX',
#     'images': [{'height': 667,
#       'url': 'https://i.scdn.co/image/86a3e71ffa1706d337405150ec3bb7b4e246db7b',
#       'width': 1000},
#      {'height': 427,
#       'url': 'https://i.scdn.co/image/aa469a2c66d8e71308dbfb3efdb116be37ccdcaa',
#       'width': 640},
#      {'height': 133,
#       'url': 'https://i.scdn.co/image/a0e5359dc08b113b293b9d46715dea3ade289ba0',
#       'width': 200},
#      {'height': 43,
#       'url': 'https://i.scdn.co/image/74c219f600ec1d671430515820392104a64be811',
#       'width': 64}],
#     'name': "Lil' Kim",
#     'popularity': 62,
#     'type': 'artist',
#     'uri': 'spotify:artist:5tth2a3v0sWwV1C7bApBdX'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1I5u5Umau1AgHl0ZbPL1oR'},
#     'followers': {'href': None, 'total': 15573},
#     'genres': ['chicano rap'],
#     'href': 'https://api.spotify.com/v1/artists/1I5u5Umau1AgHl0ZbPL1oR',
#     'id': '1I5u5Umau1AgHl0ZbPL1oR',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/9a690f19d1f22f37c2d8ea2269d5d13c227059c7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/8a8413a32bf7407d8e3c7705fb24db7b817d7804',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/06ce7932e56c32475af8927bfffcce0d76475be8',
#       'width': 64}],
#     'name': 'Lil Cuete',
#     'popularity': 40,
#     'type': 'artist',
#     'uri': 'spotify:artist:1I5u5Umau1AgHl0ZbPL1oR'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3QnIBUOS4mUzs67rZ8r4c9'},
#     'followers': {'href': None, 'total': 5331},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3QnIBUOS4mUzs67rZ8r4c9',
#     'id': '3QnIBUOS4mUzs67rZ8r4c9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/e67d6752b4bc97f8e62e3bad2020d1a771543329',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/252344a7a2903b910fe462fb1d03e4050182d7ad',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/4481d09538ecb2554f01dec59f05dd050d1b03b9',
#       'width': 64}],
#     'name': 'Lil Phat',
#     'popularity': 39,
#     'type': 'artist',
#     'uri': 'spotify:artist:3QnIBUOS4mUzs67rZ8r4c9'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3FNZcjyqT7F5upP99JV0oN'},
#     'followers': {'href': None, 'total': 14521},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3FNZcjyqT7F5upP99JV0oN',
#     'id': '3FNZcjyqT7F5upP99JV0oN',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/f7a2070d4432472565f88e4d8e25f61de58bfde9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/97e0127d38fd5f0b2e9c5fd593a42148f26ee8c7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/c8c722d37914c9bd4f1b1af5b1c0e152e3e74c19',
#       'width': 64}],
#     'name': 'Lil Debbie',
#     'popularity': 43,
#     'type': 'artist',
#     'uri': 'spotify:artist:3FNZcjyqT7F5upP99JV0oN'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/564gvOqSRcQoYAhaBpTiK2'},
#     'followers': {'href': None, 'total': 14832},
#     'genres': ['jerk'],
#     'href': 'https://api.spotify.com/v1/artists/564gvOqSRcQoYAhaBpTiK2',
#     'id': '564gvOqSRcQoYAhaBpTiK2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/5280b8361231a8275ef9aeaa4e4d9a7701790eb5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/112c7e13cf136d3389ac4e2568af3cb1a02285b7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/0c0031c220e6536650161d837192c64168690d86',
#       'width': 64}],
#     'name': 'Lil Twist',
#     'popularity': 39,
#     'type': 'artist',
#     'uri': 'spotify:artist:564gvOqSRcQoYAhaBpTiK2'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5EQERGi7ffHvHsv3bnqzBn'},
#     'followers': {'href': None, 'total': 2123},
#     'genres': ['deep trap'],
#     'href': 'https://api.spotify.com/v1/artists/5EQERGi7ffHvHsv3bnqzBn',
#     'id': '5EQERGi7ffHvHsv3bnqzBn',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/b05aaee4b347f25bd1f190a47d2a04a30db96ee4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/7cc46db0ae9aca73de9ce788ffee37711af092db',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/e39030f343a1365761a1778a873a369573fb5e11',
#       'width': 64}],
#     'name': 'Lil Trill',
#     'popularity': 37,
#     'type': 'artist',
#     'uri': 'spotify:artist:5EQERGi7ffHvHsv3bnqzBn'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5YZZbPdI7P7te3lW3dTpzK'},
#     'followers': {'href': None, 'total': 318},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5YZZbPdI7P7te3lW3dTpzK',
#     'id': '5YZZbPdI7P7te3lW3dTpzK',
#     'images': [{'height': 960,
#       'url': 'https://i.scdn.co/image/171bcf1727e696bb7abe4af8c339654a03335c75',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/4fc43fb0bb59f30f92a4a61267b2d68a16441041',
#       'width': 200},
#      {'height': 96,
#       'url': 'https://i.scdn.co/image/13157eee5b9392e4c9eddced209e32eac2540000',
#       'width': 64}],
#     'name': 'Lil Twon',
#     'popularity': 38,
#     'type': 'artist',
#     'uri': 'spotify:artist:5YZZbPdI7P7te3lW3dTpzK'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2jXwYLNnCxNavms4mc1DYM'},
#     'followers': {'href': None, 'total': 897},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2jXwYLNnCxNavms4mc1DYM',
#     'id': '2jXwYLNnCxNavms4mc1DYM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/c836e08658864e66d993dd082d22d6dfee7d4645',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/255d752315107f40dc7ff7d9deff7955f6ca569e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/93902d4634605f54f6d16df88d4bd7bbf2b5ae4a',
#       'width': 64}],
#     'name': 'Lil AJ',
#     'popularity': 37,
#     'type': 'artist',
#     'uri': 'spotify:artist:2jXwYLNnCxNavms4mc1DYM'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6zSBkdKFLKKggDtE3amfCk'},
#     'followers': {'href': None, 'total': 1330},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6zSBkdKFLKKggDtE3amfCk',
#     'id': '6zSBkdKFLKKggDtE3amfCk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/5711c2a25c98d389ae955cb562dedcaca06a08d6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/bc2a5a16f5654aeae7edbc00cd4ae95499d1a561',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/1882daf793d5734228f415a9e9c3ac568326fa90',
#       'width': 64}],
#     'name': 'Lil Lonnie',
#     'popularity': 37,
#     'type': 'artist',
#     'uri': 'spotify:artist:6zSBkdKFLKKggDtE3amfCk'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1mmlWsyPJvvxMdabcGJjRn'},
#     'followers': {'href': None, 'total': 170},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1mmlWsyPJvvxMdabcGJjRn',
#     'id': '1mmlWsyPJvvxMdabcGJjRn',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/60159d868f6ceb3433cc4d9c6ad9d551c142a1ec',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/d84f042b1e6785cac700ead5797b250d0e00744d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/98efe8330240c282b4a87fd98bf90f8c93f869cc',
#       'width': 64}],
#     'name': 'Lil Boom',
#     'popularity': 35,
#     'type': 'artist',
#     'uri': 'spotify:artist:1mmlWsyPJvvxMdabcGJjRn'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3rWaFjgOi5mjQfllMfN3VI'},
#     'followers': {'href': None, 'total': 1340},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3rWaFjgOi5mjQfllMfN3VI',
#     'id': '3rWaFjgOi5mjQfllMfN3VI',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/27cd70424eb57712af1a3f02d8c065fb8248c6f7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/5df4c3e9982888cfc853591361bde30b26e4b182',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/cf681ac1c01f676cb8848fc3c1c1e91af4981940',
#       'width': 64}],
#     'name': 'Lil Goofy',
#     'popularity': 35,
#     'type': 'artist',
#     'uri': 'spotify:artist:3rWaFjgOi5mjQfllMfN3VI'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6tslWi0BXiDdtChermDzkU'},
#     'followers': {'href': None, 'total': 4743},
#     'genres': ['chicano rap'],
#     'href': 'https://api.spotify.com/v1/artists/6tslWi0BXiDdtChermDzkU',
#     'id': '6tslWi0BXiDdtChermDzkU',
#     'images': [{'height': 445,
#       'url': 'https://i.scdn.co/image/f3e380e2bb1706ccc3ff3136a5909b2df62fc8e6',
#       'width': 999},
#      {'height': 285,
#       'url': 'https://i.scdn.co/image/b422c3b95293beb367cf38901631d5537c6431b1',
#       'width': 640},
#      {'height': 89,
#       'url': 'https://i.scdn.co/image/c827b7877bde6b4295d708b75ec78bb493ad7245',
#       'width': 200},
#      {'height': 29,
#       'url': 'https://i.scdn.co/image/f9ee61c0fc0e027f2a87cb2a610637ebce8e8e4c',
#       'width': 64}],
#     'name': 'Mr. Lil One',
#     'popularity': 36,
#     'type': 'artist',
#     'uri': 'spotify:artist:6tslWi0BXiDdtChermDzkU'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4E9dumwOMLlTyXUp1i2WdI'},
#     'followers': {'href': None, 'total': 679},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4E9dumwOMLlTyXUp1i2WdI',
#     'id': '4E9dumwOMLlTyXUp1i2WdI',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/0248b931d044d7cd9e04e985dd60e262d47bd48e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/2e0750e4f4f1b6faef4694e8cdc7be2ea7943025',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/71627015b26cd42d2d4912b0b728d26d5aa021bc',
#       'width': 64}],
#     'name': 'Lil Haiti',
#     'popularity': 36,
#     'type': 'artist',
#     'uri': 'spotify:artist:4E9dumwOMLlTyXUp1i2WdI'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/069qBEK34YGoX7nSIT74Eg'},
#     'followers': {'href': None, 'total': 1763},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/069qBEK34YGoX7nSIT74Eg',
#     'id': '069qBEK34YGoX7nSIT74Eg',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/00f49af07547e77af2b67f621c8fd77be607f166',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/760852e9190609b0bf7bab4c5ba3fd14654956a3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/390f2cc02272310ae41fb67ef92b7bf226262be6',
#       'width': 64}],
#     'name': 'Lil Flash',
#     'popularity': 38,
#     'type': 'artist',
#     'uri': 'spotify:artist:069qBEK34YGoX7nSIT74Eg'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/38XiDu0kK3Z5jdHUDqBzNT'},
#     'followers': {'href': None, 'total': 1658},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/38XiDu0kK3Z5jdHUDqBzNT',
#     'id': '38XiDu0kK3Z5jdHUDqBzNT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/63f06a92ecd7974e1360c1fbf318285b52208594',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/2cc112871d0755a7b08c8640d77c027dbe2fefff',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/37245d0c87fc06fd2ed5aab80207c2a70b688e9d',
#       'width': 64}],
#     'name': 'Lil Kesh',
#     'popularity': 39,
#     'type': 'artist',
#     'uri': 'spotify:artist:38XiDu0kK3Z5jdHUDqBzNT'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/43BqexhEx5NKF7VfeOYP9m'},
#     'followers': {'href': None, 'total': 985},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/43BqexhEx5NKF7VfeOYP9m',
#     'id': '43BqexhEx5NKF7VfeOYP9m',
#     'images': [{'height': 500,
#       'url': 'https://i.scdn.co/image/19b3c85c69a68790f2edef06bd2da9e51ee88a44',
#       'width': 500},
#      {'height': 200,
#       'url': 'https://i.scdn.co/image/ced2056dc33e8b3c318560ecdc393c5e79939927',
#       'width': 200},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/08f5c3a7abf35edf216ce353f611b37d1251e2ca',
#       'width': 64}],
#     'name': 'Lil Cray',
#     'popularity': 35,
#     'type': 'artist',
#     'uri': 'spotify:artist:43BqexhEx5NKF7VfeOYP9m'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2Kv0ApBohrL213X9avMrEn'},
#     'followers': {'href': None, 'total': 9421},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2Kv0ApBohrL213X9avMrEn',
#     'id': '2Kv0ApBohrL213X9avMrEn',
#     'images': [{'height': 1500,
#       'url': 'https://i.scdn.co/image/9b1581aa35fa3461ad886fe8999f3757d3292fb7',
#       'width': 1000},
#      {'height': 960,
#       'url': 'https://i.scdn.co/image/7105c05c8533bf8689937a1d37613db9576b73d8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/79b367700f460ea27a3f0ad56ac2596d3f220ae1',
#       'width': 200},
#      {'height': 96,
#       'url': 'https://i.scdn.co/image/9bf3f51c3475fcfa7e2cac1780c97dff19cb47c4',
#       'width': 64}],
#     'name': 'Lil Silva',
#     'popularity': 43,
#     'type': 'artist',
#     'uri': 'spotify:artist:2Kv0ApBohrL213X9avMrEn'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4IFVaKBbEO8Qkurg6nmoc4'},
#     'followers': {'href': None, 'total': 3286},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4IFVaKBbEO8Qkurg6nmoc4',
#     'id': '4IFVaKBbEO8Qkurg6nmoc4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/a71e6d63cee27fbf8d35783319f27517544729a6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/6872135b1c7727339bc927f76b6502e7b0626bb4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/b9704a6bad87cf9e221824ac02f09dc8569c5fc6',
#       'width': 64}],
#     'name': 'Lil Rue',
#     'popularity': 34,
#     'type': 'artist',
#     'uri': 'spotify:artist:4IFVaKBbEO8Qkurg6nmoc4'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5CY0QKsbUBpQJIE2yycsYi'},
#     'followers': {'href': None, 'total': 1623},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5CY0QKsbUBpQJIE2yycsYi',
#     'id': '5CY0QKsbUBpQJIE2yycsYi',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/a1ab38ca89a4640ba1306c5f2ade50750194e5d9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/5ba8136190e12f51a128855f107afcfd446e63bd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/b2c57e0ba16bb50a92e84a1776bc6a324d858c2c',
#       'width': 64}],
#     'name': 'Lil Eddie',
#     'popularity': 41,
#     'type': 'artist',
#     'uri': 'spotify:artist:5CY0QKsbUBpQJIE2yycsYi'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4vIlHBnzWKbmWe8ZOkT1ZT'},
#     'followers': {'href': None, 'total': 1129},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4vIlHBnzWKbmWe8ZOkT1ZT',
#     'id': '4vIlHBnzWKbmWe8ZOkT1ZT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/0f0c996d27335179f4136620e95d9c3245147806',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/923c54f357bb8fbba8623cadb9f4194e90de760c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/85d4cf1f11ec3ba3481a9414fbb5dc5801abe086',
#       'width': 64}],
#     'name': 'Lil Yase',
#     'popularity': 33,
#     'type': 'artist',
#     'uri': 'spotify:artist:4vIlHBnzWKbmWe8ZOkT1ZT'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/65npPa1U4cgobX9wU7Jgpb'},
#     'followers': {'href': None, 'total': 12848},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/65npPa1U4cgobX9wU7Jgpb',
#     'id': '65npPa1U4cgobX9wU7Jgpb',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/97bfe3f9251d35d9a358d8e937d3a6365c7a674a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/201eee225cd733022b0e78f6fbfe04861d898a84',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/80f03593b486eb3b70f9c035097d669e7704c328',
#       'width': 64}],
#     'name': 'Lil Wayne, DJ Drama',
#     'popularity': 35,
#     'type': 'artist',
#     'uri': 'spotify:artist:65npPa1U4cgobX9wU7Jgpb'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5HPsVk1MblCoa44WLJsQwN'},
#     'followers': {'href': None, 'total': 5889},
#     'genres': ['freestyle'],
#     'href': 'https://api.spotify.com/v1/artists/5HPsVk1MblCoa44WLJsQwN',
#     'id': '5HPsVk1MblCoa44WLJsQwN',
#     'images': [{'height': 482,
#       'url': 'https://i.scdn.co/image/9e2c6bb7420bdfe0675255200e6a90fbe6744514',
#       'width': 720},
#      {'height': 428,
#       'url': 'https://i.scdn.co/image/861aeb62673db5c88a4938462051496d54a88e14',
#       'width': 639},
#      {'height': 134,
#       'url': 'https://i.scdn.co/image/3bcf3420690356d33c72e6d699a6e087a2f287d4',
#       'width': 200},
#      {'height': 43,
#       'url': 'https://i.scdn.co/image/b807785791281b511ee7e545825f5508648914b0',
#       'width': 64}],
#     'name': 'Lil Suzy',
#     'popularity': 34,
#     'type': 'artist',
#     'uri': 'spotify:artist:5HPsVk1MblCoa44WLJsQwN'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1cEHxCgGlEgqBc91YOcAEQ'},
#     'followers': {'href': None, 'total': 16302},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1cEHxCgGlEgqBc91YOcAEQ',
#     'id': '1cEHxCgGlEgqBc91YOcAEQ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/a7969adf46dff0c450120388bef4e760e2443a66',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/9f155a53e2c7be92a0846befc94162e84a5e02b9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/7b434e7ce5acc91a1f1df22a4af376281e98dbbe',
#       'width': 64}],
#     'name': 'Lil Mouse',
#     'popularity': 34,
#     'type': 'artist',
#     'uri': 'spotify:artist:1cEHxCgGlEgqBc91YOcAEQ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/69swdLSkKxCQBMYJ55O2mA'},
#     'followers': {'href': None, 'total': 1705},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/69swdLSkKxCQBMYJ55O2mA',
#     'id': '69swdLSkKxCQBMYJ55O2mA',
#     'images': [{'height': 300,
#       'url': 'https://i.scdn.co/image/0b0c4aa534c6203577fd01f13a00807e4635851c',
#       'width': 200},
#      {'height': 96,
#       'url': 'https://i.scdn.co/image/ddef4f63a39e9007bef9adab285e7c51ce345848',
#       'width': 64}],
#     'name': 'Lil C',
#     'popularity': 33,
#     'type': 'artist',
#     'uri': 'spotify:artist:69swdLSkKxCQBMYJ55O2mA'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1qKzKUnuQsjB83hBZffoq0'},
#     'followers': {'href': None, 'total': 1828},
#     'genres': ['soca'],
#     'href': 'https://api.spotify.com/v1/artists/1qKzKUnuQsjB83hBZffoq0',
#     'id': '1qKzKUnuQsjB83hBZffoq0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/4008de208a4462c926c09d5d341638abaa734d9d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/bd35dfb47d9719d7c94d185b55364a63d9a6e37d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/5d11e2608b6c526ae1bc76a09b0357ac3d802bfe',
#       'width': 64}],
#     'name': 'Lil Rick',
#     'popularity': 39,
#     'type': 'artist',
#     'uri': 'spotify:artist:1qKzKUnuQsjB83hBZffoq0'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3GH3KD2078kLPpEkN1UN26'},
#     'followers': {'href': None, 'total': 1396},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3GH3KD2078kLPpEkN1UN26',
#     'id': '3GH3KD2078kLPpEkN1UN26',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/076a261d997d38ebbb55041a67bd4e00d960ce7e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/fbfc9a3a04437bba987ff1c2f4f38358b809b155',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/0b3c65e61d127766aa052b33bcddd796d06d0f28',
#       'width': 64}],
#     'name': 'Lil June',
#     'popularity': 32,
#     'type': 'artist',
#     'uri': 'spotify:artist:3GH3KD2078kLPpEkN1UN26'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0zn6yzsbWj3EPMgOTqfG5k'},
#     'followers': {'href': None, 'total': 130},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/0zn6yzsbWj3EPMgOTqfG5k',
#     'id': '0zn6yzsbWj3EPMgOTqfG5k',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/35638d3cfbc1b763aeb111c9273e724bdef12aa4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ecd0a4a293cd661df2a8da127c343c46d4f7d11e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/a9d06155df08da255a54a8dc598961b5ff5a3958',
#       'width': 64}],
#     'name': 'Lil E',
#     'popularity': 34,
#     'type': 'artist',
#     'uri': 'spotify:artist:0zn6yzsbWj3EPMgOTqfG5k'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6JUnsP7jmvYmdhbg7lTMQj'},
#     'followers': {'href': None, 'total': 110},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6JUnsP7jmvYmdhbg7lTMQj',
#     'id': '6JUnsP7jmvYmdhbg7lTMQj',
#     'images': [],
#     'name': 'Lil Fate',
#     'popularity': 34,
#     'type': 'artist',
#     'uri': 'spotify:artist:6JUnsP7jmvYmdhbg7lTMQj'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Q5sPmM8j4SpMqL4UA1DtS'},
#     'followers': {'href': None, 'total': 19887},
#     'genres': ['crunk', 'dirty south rap'],
#     'href': 'https://api.spotify.com/v1/artists/4Q5sPmM8j4SpMqL4UA1DtS',
#     'id': '4Q5sPmM8j4SpMqL4UA1DtS',
#     'images': [{'height': 810,
#       'url': 'https://i.scdn.co/image/3767913038db1bbb8e971a3f93b4eb2c86b402c1',
#       'width': 1000},
#      {'height': 519,
#       'url': 'https://i.scdn.co/image/dcc17914d52f5194f21ed73c2272701f940be220',
#       'width': 640},
#      {'height': 162,
#       'url': 'https://i.scdn.co/image/a645742d2b72d97d0abeb35eb880439f11013b1d',
#       'width': 200},
#      {'height': 52,
#       'url': 'https://i.scdn.co/image/d2f390e207477cdd0e2229429593f7dd99f08e54',
#       'width': 64}],
#     'name': "Lil' Flip",
#     'popularity': 49,
#     'type': 'artist',
#     'uri': 'spotify:artist:4Q5sPmM8j4SpMqL4UA1DtS'}],
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/search?query=Lil&offset=50&limit=50&type=artist',
#   'offset': 0,
#   'previous': None,
#   'total': 4502}}

# %%
Lil_data.keys()
# Out:
# dict_keys(['artists'])

# %%
Lil_data['artists'].keys()
# Out:
# dict_keys(['offset', 'href', 'previous', 'limit', 'next', 'items', 'total'])

# %%
Lil_artists = Lil_data['artists']['items']

# %%
#With "Lil Wayne" and "Lil Kim" there are a lot of "Lil" musicians. Do a search and print a list of 50 
#that are playable in the USA (or the country of your choice), along with their popularity score.

for artist in Lil_artists:
    print(artist['name'],"has the popularity of", artist['popularity'])
# Out:
# Lil Wayne has the popularity of 86
# Lil Yachty has the popularity of 72
# Lil Uzi Vert has the popularity of 72
# Lil Dicky has the popularity of 68
# Boosie Badazz has the popularity of 67
# Lil Jon has the popularity of 72
# King Lil G has the popularity of 61
# Lil Durk has the popularity of 60
# Lil Jon & The East Side Boyz has the popularity of 60
# Lil Bibby has the popularity of 54
# G Herbo has the popularity of 53
# Lil Rob has the popularity of 50
# Lil Reese has the popularity of 50
# Lil Keke has the popularity of 48
# Bow Wow has the popularity of 57
# Lil Scrappy has the popularity of 48
# Lil Wyte has the popularity of 50
# Lil Blood has the popularity of 45
# Lil Snupe has the popularity of 45
# Lil Mama has the popularity of 45
# Lil B has the popularity of 44
# Lil' Kim has the popularity of 62
# Lil Cuete has the popularity of 40
# Lil Phat has the popularity of 39
# Lil Debbie has the popularity of 43
# Lil Twist has the popularity of 39
# Lil Trill has the popularity of 37
# Lil Twon has the popularity of 38
# Lil AJ has the popularity of 37
# Lil Lonnie has the popularity of 37
# Lil Boom has the popularity of 35
# Lil Goofy has the popularity of 35
# Mr. Lil One has the popularity of 36
# Lil Haiti has the popularity of 36
# Lil Flash has the popularity of 38
# Lil Kesh has the popularity of 39
# Lil Cray has the popularity of 35
# Lil Silva has the popularity of 43
# Lil Rue has the popularity of 34
# Lil Eddie has the popularity of 41
# Lil Yase has the popularity of 33
# Lil Wayne, DJ Drama has the popularity of 35
# Lil Suzy has the popularity of 34
# Lil Mouse has the popularity of 34
# Lil C has the popularity of 33
# Lil Rick has the popularity of 39
# Lil June has the popularity of 32
# Lil E has the popularity of 34
# Lil Fate has the popularity of 34
# Lil' Flip has the popularity of 49

# %%
# What genres are most represented in the search results? Edit your previous printout to also display a list of their genres 
#in the format "GENRE_1, GENRE_2, GENRE_3". If there are no genres, print "No genres listed".
#Tip: "how to join a list Python" might be a helpful search
# if len(artist['genres']) == 0 )
# print ("no genres")
# else:
#     genres = ", ".join(artist['genres'])

genre_list = []
genre_loop = Lil_data['artists']['items']

for item in genre_loop:
    #print(item['genres'])
    item_gen = item['genres']
    for i in item_gen:
        genre_list.append(i)
#print(sorted(genre_list))

#COUNTING the most 

genre_counter = {}
for word in genre_list:
    if word in genre_counter:
        genre_counter[word] += 1
    else:
        genre_counter[word] = 1
popular_genre = sorted(genre_counter, key = genre_counter.get, reverse = True)
top_genre = popular_genre[:1]
print("The genre most represented is", top_genre)

#COUNTING the most with count to confirm

from collections import Counter
count = Counter(genre_list)
most_count = count.most_common(1)
print("The genre most represented and the count are", most_count)

print("-----------------------------------------------------")
    


for artist in Lil_artists:
    num_genres = 'no genres listed'
    if len(artist['genres']) > 0:
        num_genres= str.join(',', (artist['genres']))
    print(artist['name'],"has the popularity of", artist['popularity'], ", and has", num_genres, "under genres")
# Out:
# The genre most represented is ['dirty south rap']
# The genre most represented and the count are [('dirty south rap', 4)]
# -----------------------------------------------------
# Lil Wayne has the popularity of 86 , and has dirty south rap,pop rap,southern hip hop,trap music under genres
# Lil Yachty has the popularity of 72 , and has no genres listed under genres
# Lil Uzi Vert has the popularity of 72 , and has no genres listed under genres
# Lil Dicky has the popularity of 68 , and has no genres listed under genres
# Boosie Badazz has the popularity of 67 , and has no genres listed under genres
# Lil Jon has the popularity of 72 , and has crunk,dirty south rap,southern hip hop under genres
# King Lil G has the popularity of 61 , and has no genres listed under genres
# Lil Durk has the popularity of 60 , and has no genres listed under genres
# Lil Jon & The East Side Boyz has the popularity of 60 , and has no genres listed under genres
# Lil Bibby has the popularity of 54 , and has no genres listed under genres
# G Herbo has the popularity of 53 , and has no genres listed under genres
# Lil Rob has the popularity of 50 , and has chicano rap,latin hip hop under genres
# Lil Reese has the popularity of 50 , and has no genres listed under genres
# Lil Keke has the popularity of 48 , and has no genres listed under genres
# Bow Wow has the popularity of 57 , and has hip pop,pop rap under genres
# Lil Scrappy has the popularity of 48 , and has crunk,dirty south rap,southern hip hop,trap music under genres
# Lil Wyte has the popularity of 50 , and has juggalo under genres
# Lil Blood has the popularity of 45 , and has no genres listed under genres
# Lil Snupe has the popularity of 45 , and has no genres listed under genres
# Lil Mama has the popularity of 45 , and has hip pop under genres
# Lil B has the popularity of 44 , and has no genres listed under genres
# Lil' Kim has the popularity of 62 , and has hip pop under genres
# Lil Cuete has the popularity of 40 , and has chicano rap under genres
# Lil Phat has the popularity of 39 , and has no genres listed under genres
# Lil Debbie has the popularity of 43 , and has no genres listed under genres
# Lil Twist has the popularity of 39 , and has jerk under genres
# Lil Trill has the popularity of 37 , and has deep trap under genres
# Lil Twon has the popularity of 38 , and has no genres listed under genres
# Lil AJ has the popularity of 37 , and has no genres listed under genres
# Lil Lonnie has the popularity of 37 , and has no genres listed under genres
# Lil Boom has the popularity of 35 , and has no genres listed under genres
# Lil Goofy has the popularity of 35 , and has no genres listed under genres
# Mr. Lil One has the popularity of 36 , and has chicano rap under genres
# Lil Haiti has the popularity of 36 , and has no genres listed under genres
# Lil Flash has the popularity of 38 , and has no genres listed under genres
# Lil Kesh has the popularity of 39 , and has no genres listed under genres
# Lil Cray has the popularity of 35 , and has no genres listed under genres
# Lil Silva has the popularity of 43 , and has no genres listed under genres
# Lil Rue has the popularity of 34 , and has no genres listed under genres
# Lil Eddie has the popularity of 41 , and has no genres listed under genres
# Lil Yase has the popularity of 33 , and has no genres listed under genres
# Lil Wayne, DJ Drama has the popularity of 35 , and has no genres listed under genres
# Lil Suzy has the popularity of 34 , and has freestyle under genres
# Lil Mouse has the popularity of 34 , and has no genres listed under genres
# Lil C has the popularity of 33 , and has no genres listed under genres
# Lil Rick has the popularity of 39 , and has soca under genres
# Lil June has the popularity of 32 , and has no genres listed under genres
# Lil E has the popularity of 34 , and has no genres listed under genres
# Lil Fate has the popularity of 34 , and has no genres listed under genres
# Lil' Flip has the popularity of 49 , and has crunk,dirty south rap under genres

# %% [markdown]
# ## LIL' GRAPHICS ##
#
# Use Excel, Illustrator or something like https://infogr.am/ to make a graphic about the Lil's, or the Lil's vs. the Biggies.
# Just a simple bar graph of their various popularities sounds good to me.
# Link to the Line Graph of Lil's Popularity chart
#
# [Lil Popularity Graph](https://infogr.am/b4473739-b764-4a24-896f-c7878796d826)

# %%
Lil_response = requests.get('https://api.spotify.com/v1/search?query=Lil&type=artist&limit=50&country=US')
Lil_data = Lil_response.json()
Lil_data
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Lil&offset=0&limit=50&type=artist',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55Aa2cqylxrFIXC767Z865'},
#     'followers': {'href': None, 'total': 2623705},
#     'genres': ['dirty south rap', 'pop rap', 'southern hip hop', 'trap music'],
#     'href': 'https://api.spotify.com/v1/artists/55Aa2cqylxrFIXC767Z865',
#     'id': '55Aa2cqylxrFIXC767Z865',
#     'images': [{'height': 1239,
#       'url': 'https://i.scdn.co/image/cf012139c3b8681b46a66bae70558a8a336ab231',
#       'width': 1000},
#      {'height': 793,
#       'url': 'https://i.scdn.co/image/fffd48d60e27901f6e9ce99423f045cb2b893944',
#       'width': 640},
#      {'height': 248,
#       'url': 'https://i.scdn.co/image/bf03141629c202e94b206f1374a39326a9d8c6ca',
#       'width': 200},
#      {'height': 79,
#       'url': 'https://i.scdn.co/image/521f99f2469883b8806a69a3a2487fdd983bd621',
#       'width': 64}],
#     'name': 'Lil Wayne',
#     'popularity': 86,
#     'type': 'artist',
#     'uri': 'spotify:artist:55Aa2cqylxrFIXC767Z865'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6icQOAFXDZKsumw3YXyusw'},
#     'followers': {'href': None, 'total': 37877},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6icQOAFXDZKsumw3YXyusw',
#     'id': '6icQOAFXDZKsumw3YXyusw',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/add25baa69fc7bfd9cfd5d87716941028c2d6736',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/3f8205117bdd028a648ad3fc925f9fb46dfa26fa',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ccc54e2911dbc5463acb401ee61489e27d991408',
#       'width': 64}],
#     'name': 'Lil Yachty',
#     'popularity': 72,
#     'type': 'artist',
#     'uri': 'spotify:artist:6icQOAFXDZKsumw3YXyusw'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4O15NlyKLIASxsJ0PrXPfz'},
#     'followers': {'href': None, 'total': 54986},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4O15NlyKLIASxsJ0PrXPfz',
#     'id': '4O15NlyKLIASxsJ0PrXPfz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/8c02344d1cb9069a5a2a9d1e860dc88b04088549',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/28ac78387ad26048ccab0b671cbaddb30a2b52da',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/6b074e198860470024e57ebbc1dda9f58088c506',
#       'width': 160}],
#     'name': 'Lil Uzi Vert',
#     'popularity': 72,
#     'type': 'artist',
#     'uri': 'spotify:artist:4O15NlyKLIASxsJ0PrXPfz'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1tqhsYv8yBBdwANFNzHtcr'},
#     'followers': {'href': None, 'total': 224686},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1tqhsYv8yBBdwANFNzHtcr',
#     'id': '1tqhsYv8yBBdwANFNzHtcr',
#     'images': [{'height': 1000,
#       'url': 'https://i.scdn.co/image/a9c000526b14038b1fe69c72b0775f125bdf08af',
#       'width': 1000},
#      {'height': 640,
#       'url': 'https://i.scdn.co/image/31eac6ae8bdd6909236b5fd729d17406cc794e2d',
#       'width': 640},
#      {'height': 200,
#       'url': 'https://i.scdn.co/image/24dcb67ddd3afc794a4b1dab4cc1a47035a0beab',
#       'width': 200},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/2d2ebd85f676535129dbb7c3a4bb96e7bfd940a7',
#       'width': 64}],
#     'name': 'Lil Dicky',
#     'popularity': 68,
#     'type': 'artist',
#     'uri': 'spotify:artist:1tqhsYv8yBBdwANFNzHtcr'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6z7xFFHxYkE9t8bwIF0Bvg'},
#     'followers': {'href': None, 'total': 220122},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6z7xFFHxYkE9t8bwIF0Bvg',
#     'id': '6z7xFFHxYkE9t8bwIF0Bvg',
#     'images': [{'height': 667,
#       'url': 'https://i.scdn.co/image/f89376b78fe94a1692a5768f8f3440a4397bfb17',
#       'width': 1000},
#      {'height': 427,
#       'url': 'https://i.scdn.co/image/fbf5353d4410a540cc74285d387d9e59d038592a',
#       'width': 640},
#      {'height': 133,
#       'url': 'https://i.scdn.co/image/39995515de01dc9eb91bc9c17d5c1921e7e54a1f',
#       'width': 200},
#      {'height': 43,
#       'url': 'https://i.scdn.co/image/b34f525381a78c72f423d74b76a47e1a1da9f7f8',
#       'width': 64}],
#     'name': 'Boosie Badazz',
#     'popularity': 67,
#     'type': 'artist',
#     'uri': 'spotify:artist:6z7xFFHxYkE9t8bwIF0Bvg'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7sfl4Xt5KmfyDs2T3SVSMK'},
#     'followers': {'href': None, 'total': 256024},
#     'genres': ['crunk', 'dirty south rap', 'southern hip hop'],
#     'href': 'https://api.spotify.com/v1/artists/7sfl4Xt5KmfyDs2T3SVSMK',
#     'id': '7sfl4Xt5KmfyDs2T3SVSMK',
#     'images': [{'height': 664,
#       'url': 'https://i.scdn.co/image/885941564eadf27b7ee86d089e87967f9e3cf612',
#       'width': 1000},
#      {'height': 425,
#       'url': 'https://i.scdn.co/image/b5495566665b41f3dc2560d37d043e4a3dc2ca41',
#       'width': 640},
#      {'height': 133,
#       'url': 'https://i.scdn.co/image/6ea9f92a43e23eaa7ced98d8773de37229b1410d',
#       'width': 200},
#      {'height': 43,
#       'url': 'https://i.scdn.co/image/ddef386b560619f296a27059874ad3fc7fd5d85d',
#       'width': 64}],
#     'name': 'Lil Jon',
#     'popularity': 72,
#     'type': 'artist',
#     'uri': 'spotify:artist:7sfl4Xt5KmfyDs2T3SVSMK'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6L3x3if9RVimruryD9LoFb'},
#     'followers': {'href': None, 'total': 64182},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6L3x3if9RVimruryD9LoFb',
#     'id': '6L3x3if9RVimruryD9LoFb',
#     'images': [{'height': 879,
#       'url': 'https://i.scdn.co/image/8942e9c0745697fa8e3e75f02aa461d722a0519d',
#       'width': 587},
#      {'height': 299,
#       'url': 'https://i.scdn.co/image/9fa49263a60cd27888e23b6c6c10c930af48114e',
#       'width': 200},
#      {'height': 96,
#       'url': 'https://i.scdn.co/image/c11e5e1e9d21cee430c1bd7c72e387422854bd6a',
#       'width': 64}],
#     'name': 'King Lil G',
#     'popularity': 61,
#     'type': 'artist',
#     'uri': 'spotify:artist:6L3x3if9RVimruryD9LoFb'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3hcs9uc56yIGFCSy9leWe7'},
#     'followers': {'href': None, 'total': 134060},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3hcs9uc56yIGFCSy9leWe7',
#     'id': '3hcs9uc56yIGFCSy9leWe7',
#     'images': [{'height': 426,
#       'url': 'https://i.scdn.co/image/2b83f7df57f9098558c63047c494dea26f2da67e',
#       'width': 999},
#      {'height': 273,
#       'url': 'https://i.scdn.co/image/42e0d88103ed677b9a6cfa426e53428127ae903d',
#       'width': 640},
#      {'height': 85,
#       'url': 'https://i.scdn.co/image/b127461c288b3777fd18ffcd3523856b6063ea1e',
#       'width': 199},
#      {'height': 27,
#       'url': 'https://i.scdn.co/image/3674b105e3a72fbb92794029846a43dc66b2fcab',
#       'width': 63}],
#     'name': 'Lil Durk',
#     'popularity': 60,
#     'type': 'artist',
#     'uri': 'spotify:artist:3hcs9uc56yIGFCSy9leWe7'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3ciRvbBIVz9fBoPbtSYq4x'},
#     'followers': {'href': None, 'total': 17043},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3ciRvbBIVz9fBoPbtSYq4x',
#     'id': '3ciRvbBIVz9fBoPbtSYq4x',
#     'images': [{'height': 500,
#       'url': 'https://i.scdn.co/image/aafc4156598fa9f8f052ec5687e648ba9120f07e',
#       'width': 554},
#      {'height': 181,
#       'url': 'https://i.scdn.co/image/7a9ccdaebabf83f763af6664d5d483c57332bc08',
#       'width': 200},
#      {'height': 58,
#       'url': 'https://i.scdn.co/image/e74083480033e85373d3deb546f16d8beedeccb3',
#       'width': 64}],
#     'name': 'Lil Jon & The East Side Boyz',
#     'popularity': 60,
#     'type': 'artist',
#     'uri': 'spotify:artist:3ciRvbBIVz9fBoPbtSYq4x'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4uSN8Y3kgFNVULUWsZEAVW'},
#     'followers': {'href': None, 'total': 44098},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4uSN8Y3kgFNVULUWsZEAVW',
#     'id': '4uSN8Y3kgFNVULUWsZEAVW',
#     'images': [{'height': 1000,
#       'url': 'https://i.scdn.co/image/07c75abe717a9b704083ef38c4446abbff10fda5',
#       'width': 1000},
#      {'height': 640,
#       'url': 'https://i.scdn.co/image/1903fd19c7279418c71da62aa02ce47cccf63e52',
#       'width': 640},
#      {'height': 200,
#       'url': 'https://i.scdn.co/image/9c37f8c40ab3594de42f1861f592f558f91d0f51',
#       'width': 200},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/efba595d34603b014b125d65f7851103185158b4',
#       'width': 64}],
#     'name': 'Lil Bibby',
#     'popularity': 54,
#     'type': 'artist',
#     'uri': 'spotify:artist:4uSN8Y3kgFNVULUWsZEAVW'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5QdEbQJ3ylBnc3gsIASAT5'},
#     'followers': {'href': None, 'total': 51466},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5QdEbQJ3ylBnc3gsIASAT5',
#     'id': '5QdEbQJ3ylBnc3gsIASAT5',
#     'images': [{'height': 667,
#       'url': 'https://i.scdn.co/image/2cb955d0b6d08e1ff70cff98b332f6debf7a8e4a',
#       'width': 1000},
#      {'height': 427,
#       'url': 'https://i.scdn.co/image/72667af5dfd57266ba7348bbec97c246986bdbfe',
#       'width': 640},
#      {'height': 133,
#       'url': 'https://i.scdn.co/image/f366a759361f875f6259ef805c76e39ff3dd754c',
#       'width': 199},
#      {'height': 43,
#       'url': 'https://i.scdn.co/image/d7b0cd61112a7b8b6326c6454652685c1d1baa1c',
#       'width': 64}],
#     'name': 'G Herbo',
#     'popularity': 53,
#     'type': 'artist',
#     'uri': 'spotify:artist:5QdEbQJ3ylBnc3gsIASAT5'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7B7TGqQe7QTVm2U6q8jzk1'},
#     'followers': {'href': None, 'total': 35824},
#     'genres': ['chicano rap', 'latin hip hop'],
#     'href': 'https://api.spotify.com/v1/artists/7B7TGqQe7QTVm2U6q8jzk1',
#     'id': '7B7TGqQe7QTVm2U6q8jzk1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/7b37dc3ed21b4236502d24a897ac02aa4eb9f183',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/457e18474f5cf18eae93e1435dcc5d2fb88c8efd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/8e7c25760b9b5d6dbc58ebc30443114fdfdfb927',
#       'width': 64}],
#     'name': 'Lil Rob',
#     'popularity': 50,
#     'type': 'artist',
#     'uri': 'spotify:artist:7B7TGqQe7QTVm2U6q8jzk1'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1bPxKZtCdjB1aj1csBJpdS'},
#     'followers': {'href': None, 'total': 23836},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1bPxKZtCdjB1aj1csBJpdS',
#     'id': '1bPxKZtCdjB1aj1csBJpdS',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/c3f33bf2d8bc3e00d0d82fd9e2a11c0594079833',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/6535600354e3ff225b5704ab3c9b4a4033746fb1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ba89cf9b97304f9f07132e8bb06293170109b64b',
#       'width': 64}],
#     'name': 'Lil Reese',
#     'popularity': 50,
#     'type': 'artist',
#     'uri': 'spotify:artist:1bPxKZtCdjB1aj1csBJpdS'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1grI9x4Uzos1Asx8JmRW6T'},
#     'followers': {'href': None, 'total': 18746},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1grI9x4Uzos1Asx8JmRW6T',
#     'id': '1grI9x4Uzos1Asx8JmRW6T',
#     'images': [{'height': 1024,
#       'url': 'https://i.scdn.co/image/3e53d37d29794eccb5fc9744b962df8f2c2b1725',
#       'width': 680},
#      {'height': 964,
#       'url': 'https://i.scdn.co/image/82bb674230d0b08e5c82e10dfe175759581e7800',
#       'width': 640},
#      {'height': 301,
#       'url': 'https://i.scdn.co/image/6f26c9f3aee5c6243f2abe210ab09446df90276b',
#       'width': 200},
#      {'height': 96,
#       'url': 'https://i.scdn.co/image/35fd540d7448475f46e06bc0b46f2ca106899910',
#       'width': 64}],
#     'name': 'Lil Keke',
#     'popularity': 48,
#     'type': 'artist',
#     'uri': 'spotify:artist:1grI9x4Uzos1Asx8JmRW6T'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7352aRY2mqSxBZwzUb6LmA'},
#     'followers': {'href': None, 'total': 118536},
#     'genres': ['hip pop', 'pop rap'],
#     'href': 'https://api.spotify.com/v1/artists/7352aRY2mqSxBZwzUb6LmA',
#     'id': '7352aRY2mqSxBZwzUb6LmA',
#     'images': [{'height': 1500,
#       'url': 'https://i.scdn.co/image/bbc23f477201e3784b54516ef2ad548794947277',
#       'width': 1000},
#      {'height': 960,
#       'url': 'https://i.scdn.co/image/4014b68d6e33d16883c70aab0972087d38e8896d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/5d3a1e94fb0fe5cf2dfb600cd7e55e8213025968',
#       'width': 200},
#      {'height': 96,
#       'url': 'https://i.scdn.co/image/6799537642674ef52cf0064aaef74cf04202c301',
#       'width': 64}],
#     'name': 'Bow Wow',
#     'popularity': 57,
#     'type': 'artist',
#     'uri': 'spotify:artist:7352aRY2mqSxBZwzUb6LmA'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5einkgXXrjhfYCyac1FANB'},
#     'followers': {'href': None, 'total': 27073},
#     'genres': ['crunk', 'dirty south rap', 'southern hip hop', 'trap music'],
#     'href': 'https://api.spotify.com/v1/artists/5einkgXXrjhfYCyac1FANB',
#     'id': '5einkgXXrjhfYCyac1FANB',
#     'images': [{'height': 300,
#       'url': 'https://i.scdn.co/image/722a084be153a03ca1bfb0c1e7c83bd4d37db156',
#       'width': 225},
#      {'height': 267,
#       'url': 'https://i.scdn.co/image/9c68dc0bb9b147bd31cb13a7b1e1d95acf481a90',
#       'width': 200},
#      {'height': 85,
#       'url': 'https://i.scdn.co/image/96df8040ad3c03f9471139786c4ea60f3998ca81',
#       'width': 64}],
#     'name': 'Lil Scrappy',
#     'popularity': 48,
#     'type': 'artist',
#     'uri': 'spotify:artist:5einkgXXrjhfYCyac1FANB'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/21O7WwRkik43ErKppxDKJq'},
#     'followers': {'href': None, 'total': 31101},
#     'genres': ['juggalo'],
#     'href': 'https://api.spotify.com/v1/artists/21O7WwRkik43ErKppxDKJq',
#     'id': '21O7WwRkik43ErKppxDKJq',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/01140761147a97db6a100c4456b531fb2d5aad82',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/0925d6476f14719b5ffd005fe0091e292c95e11e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/b232b4badce8651c11907c06ed6defcfc5616854',
#       'width': 64}],
#     'name': 'Lil Wyte',
#     'popularity': 50,
#     'type': 'artist',
#     'uri': 'spotify:artist:21O7WwRkik43ErKppxDKJq'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/74nSA5FdDOuuLw7Rn5JnuP'},
#     'followers': {'href': None, 'total': 5524},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/74nSA5FdDOuuLw7Rn5JnuP',
#     'id': '74nSA5FdDOuuLw7Rn5JnuP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/fc222056c3c65e02c96c3e94847a74ba7920757e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/052a2ef46226fa25801224fd676ba4abbb7da15a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/b3a4a57f6da39a5af2b2c56479819754caa51d35',
#       'width': 64}],
#     'name': 'Lil Blood',
#     'popularity': 45,
#     'type': 'artist',
#     'uri': 'spotify:artist:74nSA5FdDOuuLw7Rn5JnuP'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/42FaEHFfyxTdZQ5W28dXnj'},
#     'followers': {'href': None, 'total': 33976},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/42FaEHFfyxTdZQ5W28dXnj',
#     'id': '42FaEHFfyxTdZQ5W28dXnj',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/89c1a0ac4f8b95c843d633493bc3657a296e3e6b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/59654d32b34cfb51000ff26fec57ab36bf1781ae',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/b3afd3776d6e3e6ed82d45b4541e8623389e347b',
#       'width': 64}],
#     'name': 'Lil Snupe',
#     'popularity': 45,
#     'type': 'artist',
#     'uri': 'spotify:artist:42FaEHFfyxTdZQ5W28dXnj'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5qK5bOC6wLtuLhG5KvU17c'},
#     'followers': {'href': None, 'total': 21107},
#     'genres': ['hip pop'],
#     'href': 'https://api.spotify.com/v1/artists/5qK5bOC6wLtuLhG5KvU17c',
#     'id': '5qK5bOC6wLtuLhG5KvU17c',
#     'images': [{'height': 750,
#       'url': 'https://i.scdn.co/image/8e33c09ff1d5d91ea47254a389c36f626775275a',
#       'width': 600},
#      {'height': 250,
#       'url': 'https://i.scdn.co/image/991889a4147550d0421dfb80621c2e161ac7e043',
#       'width': 200},
#      {'height': 80,
#       'url': 'https://i.scdn.co/image/253d651a020406eb7c264304803463badabfe8cb',
#       'width': 64}],
#     'name': 'Lil Mama',
#     'popularity': 45,
#     'type': 'artist',
#     'uri': 'spotify:artist:5qK5bOC6wLtuLhG5KvU17c'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4dqh62yIzDBmrMeBOLiP5F'},
#     'followers': {'href': None, 'total': 224},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4dqh62yIzDBmrMeBOLiP5F',
#     'id': '4dqh62yIzDBmrMeBOLiP5F',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/5fbeb835c159b8de635ef8f5c6cc002ce138aec2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/3002b77643ae099b657a5eca5f99a79ca064b2f7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/73507e320c68d9890524a15f2eca9390a9fec455',
#       'width': 64}],
#     'name': 'Lil B',
#     'popularity': 44,
#     'type': 'artist',
#     'uri': 'spotify:artist:4dqh62yIzDBmrMeBOLiP5F'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5tth2a3v0sWwV1C7bApBdX'},
#     'followers': {'href': None, 'total': 70213},
#     'genres': ['hip pop'],
#     'href': 'https://api.spotify.com/v1/artists/5tth2a3v0sWwV1C7bApBdX',
#     'id': '5tth2a3v0sWwV1C7bApBdX',
#     'images': [{'height': 667,
#       'url': 'https://i.scdn.co/image/86a3e71ffa1706d337405150ec3bb7b4e246db7b',
#       'width': 1000},
#      {'height': 427,
#       'url': 'https://i.scdn.co/image/aa469a2c66d8e71308dbfb3efdb116be37ccdcaa',
#       'width': 640},
#      {'height': 133,
#       'url': 'https://i.scdn.co/image/a0e5359dc08b113b293b9d46715dea3ade289ba0',
#       'width': 200},
#      {'height': 43,
#       'url': 'https://i.scdn.co/image/74c219f600ec1d671430515820392104a64be811',
#       'width': 64}],
#     'name': "Lil' Kim",
#     'popularity': 62,
#     'type': 'artist',
#     'uri': 'spotify:artist:5tth2a3v0sWwV1C7bApBdX'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1I5u5Umau1AgHl0ZbPL1oR'},
#     'followers': {'href': None, 'total': 15573},
#     'genres': ['chicano rap'],
#     'href': 'https://api.spotify.com/v1/artists/1I5u5Umau1AgHl0ZbPL1oR',
#     'id': '1I5u5Umau1AgHl0ZbPL1oR',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/9a690f19d1f22f37c2d8ea2269d5d13c227059c7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/8a8413a32bf7407d8e3c7705fb24db7b817d7804',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/06ce7932e56c32475af8927bfffcce0d76475be8',
#       'width': 64}],
#     'name': 'Lil Cuete',
#     'popularity': 40,
#     'type': 'artist',
#     'uri': 'spotify:artist:1I5u5Umau1AgHl0ZbPL1oR'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3QnIBUOS4mUzs67rZ8r4c9'},
#     'followers': {'href': None, 'total': 5331},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3QnIBUOS4mUzs67rZ8r4c9',
#     'id': '3QnIBUOS4mUzs67rZ8r4c9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/e67d6752b4bc97f8e62e3bad2020d1a771543329',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/252344a7a2903b910fe462fb1d03e4050182d7ad',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/4481d09538ecb2554f01dec59f05dd050d1b03b9',
#       'width': 64}],
#     'name': 'Lil Phat',
#     'popularity': 39,
#     'type': 'artist',
#     'uri': 'spotify:artist:3QnIBUOS4mUzs67rZ8r4c9'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3FNZcjyqT7F5upP99JV0oN'},
#     'followers': {'href': None, 'total': 14521},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3FNZcjyqT7F5upP99JV0oN',
#     'id': '3FNZcjyqT7F5upP99JV0oN',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/f7a2070d4432472565f88e4d8e25f61de58bfde9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/97e0127d38fd5f0b2e9c5fd593a42148f26ee8c7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/c8c722d37914c9bd4f1b1af5b1c0e152e3e74c19',
#       'width': 64}],
#     'name': 'Lil Debbie',
#     'popularity': 43,
#     'type': 'artist',
#     'uri': 'spotify:artist:3FNZcjyqT7F5upP99JV0oN'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/564gvOqSRcQoYAhaBpTiK2'},
#     'followers': {'href': None, 'total': 14832},
#     'genres': ['jerk'],
#     'href': 'https://api.spotify.com/v1/artists/564gvOqSRcQoYAhaBpTiK2',
#     'id': '564gvOqSRcQoYAhaBpTiK2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/5280b8361231a8275ef9aeaa4e4d9a7701790eb5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/112c7e13cf136d3389ac4e2568af3cb1a02285b7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/0c0031c220e6536650161d837192c64168690d86',
#       'width': 64}],
#     'name': 'Lil Twist',
#     'popularity': 39,
#     'type': 'artist',
#     'uri': 'spotify:artist:564gvOqSRcQoYAhaBpTiK2'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5EQERGi7ffHvHsv3bnqzBn'},
#     'followers': {'href': None, 'total': 2123},
#     'genres': ['deep trap'],
#     'href': 'https://api.spotify.com/v1/artists/5EQERGi7ffHvHsv3bnqzBn',
#     'id': '5EQERGi7ffHvHsv3bnqzBn',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/b05aaee4b347f25bd1f190a47d2a04a30db96ee4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/7cc46db0ae9aca73de9ce788ffee37711af092db',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/e39030f343a1365761a1778a873a369573fb5e11',
#       'width': 64}],
#     'name': 'Lil Trill',
#     'popularity': 37,
#     'type': 'artist',
#     'uri': 'spotify:artist:5EQERGi7ffHvHsv3bnqzBn'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5YZZbPdI7P7te3lW3dTpzK'},
#     'followers': {'href': None, 'total': 318},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5YZZbPdI7P7te3lW3dTpzK',
#     'id': '5YZZbPdI7P7te3lW3dTpzK',
#     'images': [{'height': 960,
#       'url': 'https://i.scdn.co/image/171bcf1727e696bb7abe4af8c339654a03335c75',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/4fc43fb0bb59f30f92a4a61267b2d68a16441041',
#       'width': 200},
#      {'height': 96,
#       'url': 'https://i.scdn.co/image/13157eee5b9392e4c9eddced209e32eac2540000',
#       'width': 64}],
#     'name': 'Lil Twon',
#     'popularity': 38,
#     'type': 'artist',
#     'uri': 'spotify:artist:5YZZbPdI7P7te3lW3dTpzK'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2jXwYLNnCxNavms4mc1DYM'},
#     'followers': {'href': None, 'total': 897},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2jXwYLNnCxNavms4mc1DYM',
#     'id': '2jXwYLNnCxNavms4mc1DYM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/c836e08658864e66d993dd082d22d6dfee7d4645',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/255d752315107f40dc7ff7d9deff7955f6ca569e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/93902d4634605f54f6d16df88d4bd7bbf2b5ae4a',
#       'width': 64}],
#     'name': 'Lil AJ',
#     'popularity': 37,
#     'type': 'artist',
#     'uri': 'spotify:artist:2jXwYLNnCxNavms4mc1DYM'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6zSBkdKFLKKggDtE3amfCk'},
#     'followers': {'href': None, 'total': 1330},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6zSBkdKFLKKggDtE3amfCk',
#     'id': '6zSBkdKFLKKggDtE3amfCk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/5711c2a25c98d389ae955cb562dedcaca06a08d6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/bc2a5a16f5654aeae7edbc00cd4ae95499d1a561',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/1882daf793d5734228f415a9e9c3ac568326fa90',
#       'width': 64}],
#     'name': 'Lil Lonnie',
#     'popularity': 37,
#     'type': 'artist',
#     'uri': 'spotify:artist:6zSBkdKFLKKggDtE3amfCk'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1mmlWsyPJvvxMdabcGJjRn'},
#     'followers': {'href': None, 'total': 170},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1mmlWsyPJvvxMdabcGJjRn',
#     'id': '1mmlWsyPJvvxMdabcGJjRn',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/60159d868f6ceb3433cc4d9c6ad9d551c142a1ec',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/d84f042b1e6785cac700ead5797b250d0e00744d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/98efe8330240c282b4a87fd98bf90f8c93f869cc',
#       'width': 64}],
#     'name': 'Lil Boom',
#     'popularity': 35,
#     'type': 'artist',
#     'uri': 'spotify:artist:1mmlWsyPJvvxMdabcGJjRn'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3rWaFjgOi5mjQfllMfN3VI'},
#     'followers': {'href': None, 'total': 1340},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3rWaFjgOi5mjQfllMfN3VI',
#     'id': '3rWaFjgOi5mjQfllMfN3VI',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/27cd70424eb57712af1a3f02d8c065fb8248c6f7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/5df4c3e9982888cfc853591361bde30b26e4b182',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/cf681ac1c01f676cb8848fc3c1c1e91af4981940',
#       'width': 64}],
#     'name': 'Lil Goofy',
#     'popularity': 35,
#     'type': 'artist',
#     'uri': 'spotify:artist:3rWaFjgOi5mjQfllMfN3VI'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6tslWi0BXiDdtChermDzkU'},
#     'followers': {'href': None, 'total': 4743},
#     'genres': ['chicano rap'],
#     'href': 'https://api.spotify.com/v1/artists/6tslWi0BXiDdtChermDzkU',
#     'id': '6tslWi0BXiDdtChermDzkU',
#     'images': [{'height': 445,
#       'url': 'https://i.scdn.co/image/f3e380e2bb1706ccc3ff3136a5909b2df62fc8e6',
#       'width': 999},
#      {'height': 285,
#       'url': 'https://i.scdn.co/image/b422c3b95293beb367cf38901631d5537c6431b1',
#       'width': 640},
#      {'height': 89,
#       'url': 'https://i.scdn.co/image/c827b7877bde6b4295d708b75ec78bb493ad7245',
#       'width': 200},
#      {'height': 29,
#       'url': 'https://i.scdn.co/image/f9ee61c0fc0e027f2a87cb2a610637ebce8e8e4c',
#       'width': 64}],
#     'name': 'Mr. Lil One',
#     'popularity': 36,
#     'type': 'artist',
#     'uri': 'spotify:artist:6tslWi0BXiDdtChermDzkU'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4E9dumwOMLlTyXUp1i2WdI'},
#     'followers': {'href': None, 'total': 679},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4E9dumwOMLlTyXUp1i2WdI',
#     'id': '4E9dumwOMLlTyXUp1i2WdI',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/0248b931d044d7cd9e04e985dd60e262d47bd48e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/2e0750e4f4f1b6faef4694e8cdc7be2ea7943025',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/71627015b26cd42d2d4912b0b728d26d5aa021bc',
#       'width': 64}],
#     'name': 'Lil Haiti',
#     'popularity': 36,
#     'type': 'artist',
#     'uri': 'spotify:artist:4E9dumwOMLlTyXUp1i2WdI'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/069qBEK34YGoX7nSIT74Eg'},
#     'followers': {'href': None, 'total': 1763},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/069qBEK34YGoX7nSIT74Eg',
#     'id': '069qBEK34YGoX7nSIT74Eg',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/00f49af07547e77af2b67f621c8fd77be607f166',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/760852e9190609b0bf7bab4c5ba3fd14654956a3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/390f2cc02272310ae41fb67ef92b7bf226262be6',
#       'width': 64}],
#     'name': 'Lil Flash',
#     'popularity': 38,
#     'type': 'artist',
#     'uri': 'spotify:artist:069qBEK34YGoX7nSIT74Eg'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/38XiDu0kK3Z5jdHUDqBzNT'},
#     'followers': {'href': None, 'total': 1658},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/38XiDu0kK3Z5jdHUDqBzNT',
#     'id': '38XiDu0kK3Z5jdHUDqBzNT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/63f06a92ecd7974e1360c1fbf318285b52208594',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/2cc112871d0755a7b08c8640d77c027dbe2fefff',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/37245d0c87fc06fd2ed5aab80207c2a70b688e9d',
#       'width': 64}],
#     'name': 'Lil Kesh',
#     'popularity': 39,
#     'type': 'artist',
#     'uri': 'spotify:artist:38XiDu0kK3Z5jdHUDqBzNT'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/43BqexhEx5NKF7VfeOYP9m'},
#     'followers': {'href': None, 'total': 985},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/43BqexhEx5NKF7VfeOYP9m',
#     'id': '43BqexhEx5NKF7VfeOYP9m',
#     'images': [{'height': 500,
#       'url': 'https://i.scdn.co/image/19b3c85c69a68790f2edef06bd2da9e51ee88a44',
#       'width': 500},
#      {'height': 200,
#       'url': 'https://i.scdn.co/image/ced2056dc33e8b3c318560ecdc393c5e79939927',
#       'width': 200},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/08f5c3a7abf35edf216ce353f611b37d1251e2ca',
#       'width': 64}],
#     'name': 'Lil Cray',
#     'popularity': 35,
#     'type': 'artist',
#     'uri': 'spotify:artist:43BqexhEx5NKF7VfeOYP9m'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2Kv0ApBohrL213X9avMrEn'},
#     'followers': {'href': None, 'total': 9421},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2Kv0ApBohrL213X9avMrEn',
#     'id': '2Kv0ApBohrL213X9avMrEn',
#     'images': [{'height': 1500,
#       'url': 'https://i.scdn.co/image/9b1581aa35fa3461ad886fe8999f3757d3292fb7',
#       'width': 1000},
#      {'height': 960,
#       'url': 'https://i.scdn.co/image/7105c05c8533bf8689937a1d37613db9576b73d8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/79b367700f460ea27a3f0ad56ac2596d3f220ae1',
#       'width': 200},
#      {'height': 96,
#       'url': 'https://i.scdn.co/image/9bf3f51c3475fcfa7e2cac1780c97dff19cb47c4',
#       'width': 64}],
#     'name': 'Lil Silva',
#     'popularity': 43,
#     'type': 'artist',
#     'uri': 'spotify:artist:2Kv0ApBohrL213X9avMrEn'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4IFVaKBbEO8Qkurg6nmoc4'},
#     'followers': {'href': None, 'total': 3286},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4IFVaKBbEO8Qkurg6nmoc4',
#     'id': '4IFVaKBbEO8Qkurg6nmoc4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/a71e6d63cee27fbf8d35783319f27517544729a6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/6872135b1c7727339bc927f76b6502e7b0626bb4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/b9704a6bad87cf9e221824ac02f09dc8569c5fc6',
#       'width': 64}],
#     'name': 'Lil Rue',
#     'popularity': 34,
#     'type': 'artist',
#     'uri': 'spotify:artist:4IFVaKBbEO8Qkurg6nmoc4'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5CY0QKsbUBpQJIE2yycsYi'},
#     'followers': {'href': None, 'total': 1623},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5CY0QKsbUBpQJIE2yycsYi',
#     'id': '5CY0QKsbUBpQJIE2yycsYi',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/a1ab38ca89a4640ba1306c5f2ade50750194e5d9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/5ba8136190e12f51a128855f107afcfd446e63bd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/b2c57e0ba16bb50a92e84a1776bc6a324d858c2c',
#       'width': 64}],
#     'name': 'Lil Eddie',
#     'popularity': 41,
#     'type': 'artist',
#     'uri': 'spotify:artist:5CY0QKsbUBpQJIE2yycsYi'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4vIlHBnzWKbmWe8ZOkT1ZT'},
#     'followers': {'href': None, 'total': 1129},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4vIlHBnzWKbmWe8ZOkT1ZT',
#     'id': '4vIlHBnzWKbmWe8ZOkT1ZT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/0f0c996d27335179f4136620e95d9c3245147806',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/923c54f357bb8fbba8623cadb9f4194e90de760c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/85d4cf1f11ec3ba3481a9414fbb5dc5801abe086',
#       'width': 64}],
#     'name': 'Lil Yase',
#     'popularity': 33,
#     'type': 'artist',
#     'uri': 'spotify:artist:4vIlHBnzWKbmWe8ZOkT1ZT'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/65npPa1U4cgobX9wU7Jgpb'},
#     'followers': {'href': None, 'total': 12848},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/65npPa1U4cgobX9wU7Jgpb',
#     'id': '65npPa1U4cgobX9wU7Jgpb',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/97bfe3f9251d35d9a358d8e937d3a6365c7a674a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/201eee225cd733022b0e78f6fbfe04861d898a84',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/80f03593b486eb3b70f9c035097d669e7704c328',
#       'width': 64}],
#     'name': 'Lil Wayne, DJ Drama',
#     'popularity': 35,
#     'type': 'artist',
#     'uri': 'spotify:artist:65npPa1U4cgobX9wU7Jgpb'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5HPsVk1MblCoa44WLJsQwN'},
#     'followers': {'href': None, 'total': 5889},
#     'genres': ['freestyle'],
#     'href': 'https://api.spotify.com/v1/artists/5HPsVk1MblCoa44WLJsQwN',
#     'id': '5HPsVk1MblCoa44WLJsQwN',
#     'images': [{'height': 482,
#       'url': 'https://i.scdn.co/image/9e2c6bb7420bdfe0675255200e6a90fbe6744514',
#       'width': 720},
#      {'height': 428,
#       'url': 'https://i.scdn.co/image/861aeb62673db5c88a4938462051496d54a88e14',
#       'width': 639},
#      {'height': 134,
#       'url': 'https://i.scdn.co/image/3bcf3420690356d33c72e6d699a6e087a2f287d4',
#       'width': 200},
#      {'height': 43,
#       'url': 'https://i.scdn.co/image/b807785791281b511ee7e545825f5508648914b0',
#       'width': 64}],
#     'name': 'Lil Suzy',
#     'popularity': 34,
#     'type': 'artist',
#     'uri': 'spotify:artist:5HPsVk1MblCoa44WLJsQwN'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1cEHxCgGlEgqBc91YOcAEQ'},
#     'followers': {'href': None, 'total': 16302},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1cEHxCgGlEgqBc91YOcAEQ',
#     'id': '1cEHxCgGlEgqBc91YOcAEQ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/a7969adf46dff0c450120388bef4e760e2443a66',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/9f155a53e2c7be92a0846befc94162e84a5e02b9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/7b434e7ce5acc91a1f1df22a4af376281e98dbbe',
#       'width': 64}],
#     'name': 'Lil Mouse',
#     'popularity': 34,
#     'type': 'artist',
#     'uri': 'spotify:artist:1cEHxCgGlEgqBc91YOcAEQ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/69swdLSkKxCQBMYJ55O2mA'},
#     'followers': {'href': None, 'total': 1705},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/69swdLSkKxCQBMYJ55O2mA',
#     'id': '69swdLSkKxCQBMYJ55O2mA',
#     'images': [{'height': 300,
#       'url': 'https://i.scdn.co/image/0b0c4aa534c6203577fd01f13a00807e4635851c',
#       'width': 200},
#      {'height': 96,
#       'url': 'https://i.scdn.co/image/ddef4f63a39e9007bef9adab285e7c51ce345848',
#       'width': 64}],
#     'name': 'Lil C',
#     'popularity': 33,
#     'type': 'artist',
#     'uri': 'spotify:artist:69swdLSkKxCQBMYJ55O2mA'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1qKzKUnuQsjB83hBZffoq0'},
#     'followers': {'href': None, 'total': 1828},
#     'genres': ['soca'],
#     'href': 'https://api.spotify.com/v1/artists/1qKzKUnuQsjB83hBZffoq0',
#     'id': '1qKzKUnuQsjB83hBZffoq0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/4008de208a4462c926c09d5d341638abaa734d9d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/bd35dfb47d9719d7c94d185b55364a63d9a6e37d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/5d11e2608b6c526ae1bc76a09b0357ac3d802bfe',
#       'width': 64}],
#     'name': 'Lil Rick',
#     'popularity': 39,
#     'type': 'artist',
#     'uri': 'spotify:artist:1qKzKUnuQsjB83hBZffoq0'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3GH3KD2078kLPpEkN1UN26'},
#     'followers': {'href': None, 'total': 1396},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3GH3KD2078kLPpEkN1UN26',
#     'id': '3GH3KD2078kLPpEkN1UN26',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/076a261d997d38ebbb55041a67bd4e00d960ce7e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/fbfc9a3a04437bba987ff1c2f4f38358b809b155',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/0b3c65e61d127766aa052b33bcddd796d06d0f28',
#       'width': 64}],
#     'name': 'Lil June',
#     'popularity': 32,
#     'type': 'artist',
#     'uri': 'spotify:artist:3GH3KD2078kLPpEkN1UN26'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0zn6yzsbWj3EPMgOTqfG5k'},
#     'followers': {'href': None, 'total': 130},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/0zn6yzsbWj3EPMgOTqfG5k',
#     'id': '0zn6yzsbWj3EPMgOTqfG5k',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/35638d3cfbc1b763aeb111c9273e724bdef12aa4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ecd0a4a293cd661df2a8da127c343c46d4f7d11e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/a9d06155df08da255a54a8dc598961b5ff5a3958',
#       'width': 64}],
#     'name': 'Lil E',
#     'popularity': 34,
#     'type': 'artist',
#     'uri': 'spotify:artist:0zn6yzsbWj3EPMgOTqfG5k'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6JUnsP7jmvYmdhbg7lTMQj'},
#     'followers': {'href': None, 'total': 110},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6JUnsP7jmvYmdhbg7lTMQj',
#     'id': '6JUnsP7jmvYmdhbg7lTMQj',
#     'images': [],
#     'name': 'Lil Fate',
#     'popularity': 34,
#     'type': 'artist',
#     'uri': 'spotify:artist:6JUnsP7jmvYmdhbg7lTMQj'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Q5sPmM8j4SpMqL4UA1DtS'},
#     'followers': {'href': None, 'total': 19887},
#     'genres': ['crunk', 'dirty south rap'],
#     'href': 'https://api.spotify.com/v1/artists/4Q5sPmM8j4SpMqL4UA1DtS',
#     'id': '4Q5sPmM8j4SpMqL4UA1DtS',
#     'images': [{'height': 810,
#       'url': 'https://i.scdn.co/image/3767913038db1bbb8e971a3f93b4eb2c86b402c1',
#       'width': 1000},
#      {'height': 519,
#       'url': 'https://i.scdn.co/image/dcc17914d52f5194f21ed73c2272701f940be220',
#       'width': 640},
#      {'height': 162,
#       'url': 'https://i.scdn.co/image/a645742d2b72d97d0abeb35eb880439f11013b1d',
#       'width': 200},
#      {'height': 52,
#       'url': 'https://i.scdn.co/image/d2f390e207477cdd0e2229429593f7dd99f08e54',
#       'width': 64}],
#     'name': "Lil' Flip",
#     'popularity': 49,
#     'type': 'artist',
#     'uri': 'spotify:artist:4Q5sPmM8j4SpMqL4UA1DtS'}],
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/search?query=Lil&offset=50&limit=50&type=artist',
#   'offset': 0,
#   'previous': None,
#   'total': 4502}}

# %%
#Use a for loop to determine who BESIDES Lil Wayne has the highest popularity rating. 
#Is it the same artist who has the largest number of followers?
name_highest = ""
name_follow =""
second_high_pop = 0
highest_pop = 0
high_follow = 0
for artist in Lil_artists:
    if (highest_pop < artist['popularity']) & (artist['name'] != "Lil Wayne"):
        #second_high_pop = highest_pop
        #name_second = artist['name']
        highest_pop = artist['popularity']
        name_highest = artist['name']

    if (high_follow < artist['followers']['total']):
        high_follow = artist ['followers']['total']
        name_follow = artist['name']
    
    #print(artist['followers']['total'])

print(name_highest, "has the second highest popularity, which is", highest_pop)
print(name_follow, "has the highest number of followers:", high_follow)
#print("the second highest popularity is", second_high_pop)
# Out:
# Lil Yachty has the second highest popularity, which is 72
# Lil Wayne has the highest number of followers: 2623705

# %%
Lil_response = requests.get('https://api.spotify.com/v1/search?query=Lil&type=artist&limit=50&country=US')
Lil_data = Lil_response.json()
Lil_data
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Lil&offset=0&limit=50&type=artist',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55Aa2cqylxrFIXC767Z865'},
#     'followers': {'href': None, 'total': 2623705},
#     'genres': ['dirty south rap', 'pop rap', 'southern hip hop', 'trap music'],
#     'href': 'https://api.spotify.com/v1/artists/55Aa2cqylxrFIXC767Z865',
#     'id': '55Aa2cqylxrFIXC767Z865',
#     'images': [{'height': 1239,
#       'url': 'https://i.scdn.co/image/cf012139c3b8681b46a66bae70558a8a336ab231',
#       'width': 1000},
#      {'height': 793,
#       'url': 'https://i.scdn.co/image/fffd48d60e27901f6e9ce99423f045cb2b893944',
#       'width': 640},
#      {'height': 248,
#       'url': 'https://i.scdn.co/image/bf03141629c202e94b206f1374a39326a9d8c6ca',
#       'width': 200},
#      {'height': 79,
#       'url': 'https://i.scdn.co/image/521f99f2469883b8806a69a3a2487fdd983bd621',
#       'width': 64}],
#     'name': 'Lil Wayne',
#     'popularity': 86,
#     'type': 'artist',
#     'uri': 'spotify:artist:55Aa2cqylxrFIXC767Z865'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6icQOAFXDZKsumw3YXyusw'},
#     'followers': {'href': None, 'total': 37877},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6icQOAFXDZKsumw3YXyusw',
#     'id': '6icQOAFXDZKsumw3YXyusw',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/add25baa69fc7bfd9cfd5d87716941028c2d6736',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/3f8205117bdd028a648ad3fc925f9fb46dfa26fa',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ccc54e2911dbc5463acb401ee61489e27d991408',
#       'width': 64}],
#     'name': 'Lil Yachty',
#     'popularity': 72,
#     'type': 'artist',
#     'uri': 'spotify:artist:6icQOAFXDZKsumw3YXyusw'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4O15NlyKLIASxsJ0PrXPfz'},
#     'followers': {'href': None, 'total': 54986},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4O15NlyKLIASxsJ0PrXPfz',
#     'id': '4O15NlyKLIASxsJ0PrXPfz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/8c02344d1cb9069a5a2a9d1e860dc88b04088549',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/28ac78387ad26048ccab0b671cbaddb30a2b52da',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/6b074e198860470024e57ebbc1dda9f58088c506',
#       'width': 160}],
#     'name': 'Lil Uzi Vert',
#     'popularity': 72,
#     'type': 'artist',
#     'uri': 'spotify:artist:4O15NlyKLIASxsJ0PrXPfz'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1tqhsYv8yBBdwANFNzHtcr'},
#     'followers': {'href': None, 'total': 224686},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1tqhsYv8yBBdwANFNzHtcr',
#     'id': '1tqhsYv8yBBdwANFNzHtcr',
#     'images': [{'height': 1000,
#       'url': 'https://i.scdn.co/image/a9c000526b14038b1fe69c72b0775f125bdf08af',
#       'width': 1000},
#      {'height': 640,
#       'url': 'https://i.scdn.co/image/31eac6ae8bdd6909236b5fd729d17406cc794e2d',
#       'width': 640},
#      {'height': 200,
#       'url': 'https://i.scdn.co/image/24dcb67ddd3afc794a4b1dab4cc1a47035a0beab',
#       'width': 200},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/2d2ebd85f676535129dbb7c3a4bb96e7bfd940a7',
#       'width': 64}],
#     'name': 'Lil Dicky',
#     'popularity': 68,
#     'type': 'artist',
#     'uri': 'spotify:artist:1tqhsYv8yBBdwANFNzHtcr'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6z7xFFHxYkE9t8bwIF0Bvg'},
#     'followers': {'href': None, 'total': 220122},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6z7xFFHxYkE9t8bwIF0Bvg',
#     'id': '6z7xFFHxYkE9t8bwIF0Bvg',
#     'images': [{'height': 667,
#       'url': 'https://i.scdn.co/image/f89376b78fe94a1692a5768f8f3440a4397bfb17',
#       'width': 1000},
#      {'height': 427,
#       'url': 'https://i.scdn.co/image/fbf5353d4410a540cc74285d387d9e59d038592a',
#       'width': 640},
#      {'height': 133,
#       'url': 'https://i.scdn.co/image/39995515de01dc9eb91bc9c17d5c1921e7e54a1f',
#       'width': 200},
#      {'height': 43,
#       'url': 'https://i.scdn.co/image/b34f525381a78c72f423d74b76a47e1a1da9f7f8',
#       'width': 64}],
#     'name': 'Boosie Badazz',
#     'popularity': 67,
#     'type': 'artist',
#     'uri': 'spotify:artist:6z7xFFHxYkE9t8bwIF0Bvg'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7sfl4Xt5KmfyDs2T3SVSMK'},
#     'followers': {'href': None, 'total': 256024},
#     'genres': ['crunk', 'dirty south rap', 'southern hip hop'],
#     'href': 'https://api.spotify.com/v1/artists/7sfl4Xt5KmfyDs2T3SVSMK',
#     'id': '7sfl4Xt5KmfyDs2T3SVSMK',
#     'images': [{'height': 664,
#       'url': 'https://i.scdn.co/image/885941564eadf27b7ee86d089e87967f9e3cf612',
#       'width': 1000},
#      {'height': 425,
#       'url': 'https://i.scdn.co/image/b5495566665b41f3dc2560d37d043e4a3dc2ca41',
#       'width': 640},
#      {'height': 133,
#       'url': 'https://i.scdn.co/image/6ea9f92a43e23eaa7ced98d8773de37229b1410d',
#       'width': 200},
#      {'height': 43,
#       'url': 'https://i.scdn.co/image/ddef386b560619f296a27059874ad3fc7fd5d85d',
#       'width': 64}],
#     'name': 'Lil Jon',
#     'popularity': 72,
#     'type': 'artist',
#     'uri': 'spotify:artist:7sfl4Xt5KmfyDs2T3SVSMK'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6L3x3if9RVimruryD9LoFb'},
#     'followers': {'href': None, 'total': 64182},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6L3x3if9RVimruryD9LoFb',
#     'id': '6L3x3if9RVimruryD9LoFb',
#     'images': [{'height': 879,
#       'url': 'https://i.scdn.co/image/8942e9c0745697fa8e3e75f02aa461d722a0519d',
#       'width': 587},
#      {'height': 299,
#       'url': 'https://i.scdn.co/image/9fa49263a60cd27888e23b6c6c10c930af48114e',
#       'width': 200},
#      {'height': 96,
#       'url': 'https://i.scdn.co/image/c11e5e1e9d21cee430c1bd7c72e387422854bd6a',
#       'width': 64}],
#     'name': 'King Lil G',
#     'popularity': 61,
#     'type': 'artist',
#     'uri': 'spotify:artist:6L3x3if9RVimruryD9LoFb'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3hcs9uc56yIGFCSy9leWe7'},
#     'followers': {'href': None, 'total': 134060},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3hcs9uc56yIGFCSy9leWe7',
#     'id': '3hcs9uc56yIGFCSy9leWe7',
#     'images': [{'height': 426,
#       'url': 'https://i.scdn.co/image/2b83f7df57f9098558c63047c494dea26f2da67e',
#       'width': 999},
#      {'height': 273,
#       'url': 'https://i.scdn.co/image/42e0d88103ed677b9a6cfa426e53428127ae903d',
#       'width': 640},
#      {'height': 85,
#       'url': 'https://i.scdn.co/image/b127461c288b3777fd18ffcd3523856b6063ea1e',
#       'width': 199},
#      {'height': 27,
#       'url': 'https://i.scdn.co/image/3674b105e3a72fbb92794029846a43dc66b2fcab',
#       'width': 63}],
#     'name': 'Lil Durk',
#     'popularity': 60,
#     'type': 'artist',
#     'uri': 'spotify:artist:3hcs9uc56yIGFCSy9leWe7'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3ciRvbBIVz9fBoPbtSYq4x'},
#     'followers': {'href': None, 'total': 17043},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3ciRvbBIVz9fBoPbtSYq4x',
#     'id': '3ciRvbBIVz9fBoPbtSYq4x',
#     'images': [{'height': 500,
#       'url': 'https://i.scdn.co/image/aafc4156598fa9f8f052ec5687e648ba9120f07e',
#       'width': 554},
#      {'height': 181,
#       'url': 'https://i.scdn.co/image/7a9ccdaebabf83f763af6664d5d483c57332bc08',
#       'width': 200},
#      {'height': 58,
#       'url': 'https://i.scdn.co/image/e74083480033e85373d3deb546f16d8beedeccb3',
#       'width': 64}],
#     'name': 'Lil Jon & The East Side Boyz',
#     'popularity': 60,
#     'type': 'artist',
#     'uri': 'spotify:artist:3ciRvbBIVz9fBoPbtSYq4x'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4uSN8Y3kgFNVULUWsZEAVW'},
#     'followers': {'href': None, 'total': 44098},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4uSN8Y3kgFNVULUWsZEAVW',
#     'id': '4uSN8Y3kgFNVULUWsZEAVW',
#     'images': [{'height': 1000,
#       'url': 'https://i.scdn.co/image/07c75abe717a9b704083ef38c4446abbff10fda5',
#       'width': 1000},
#      {'height': 640,
#       'url': 'https://i.scdn.co/image/1903fd19c7279418c71da62aa02ce47cccf63e52',
#       'width': 640},
#      {'height': 200,
#       'url': 'https://i.scdn.co/image/9c37f8c40ab3594de42f1861f592f558f91d0f51',
#       'width': 200},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/efba595d34603b014b125d65f7851103185158b4',
#       'width': 64}],
#     'name': 'Lil Bibby',
#     'popularity': 54,
#     'type': 'artist',
#     'uri': 'spotify:artist:4uSN8Y3kgFNVULUWsZEAVW'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5QdEbQJ3ylBnc3gsIASAT5'},
#     'followers': {'href': None, 'total': 51466},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5QdEbQJ3ylBnc3gsIASAT5',
#     'id': '5QdEbQJ3ylBnc3gsIASAT5',
#     'images': [{'height': 667,
#       'url': 'https://i.scdn.co/image/2cb955d0b6d08e1ff70cff98b332f6debf7a8e4a',
#       'width': 1000},
#      {'height': 427,
#       'url': 'https://i.scdn.co/image/72667af5dfd57266ba7348bbec97c246986bdbfe',
#       'width': 640},
#      {'height': 133,
#       'url': 'https://i.scdn.co/image/f366a759361f875f6259ef805c76e39ff3dd754c',
#       'width': 199},
#      {'height': 43,
#       'url': 'https://i.scdn.co/image/d7b0cd61112a7b8b6326c6454652685c1d1baa1c',
#       'width': 64}],
#     'name': 'G Herbo',
#     'popularity': 53,
#     'type': 'artist',
#     'uri': 'spotify:artist:5QdEbQJ3ylBnc3gsIASAT5'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7B7TGqQe7QTVm2U6q8jzk1'},
#     'followers': {'href': None, 'total': 35824},
#     'genres': ['chicano rap', 'latin hip hop'],
#     'href': 'https://api.spotify.com/v1/artists/7B7TGqQe7QTVm2U6q8jzk1',
#     'id': '7B7TGqQe7QTVm2U6q8jzk1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/7b37dc3ed21b4236502d24a897ac02aa4eb9f183',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/457e18474f5cf18eae93e1435dcc5d2fb88c8efd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/8e7c25760b9b5d6dbc58ebc30443114fdfdfb927',
#       'width': 64}],
#     'name': 'Lil Rob',
#     'popularity': 50,
#     'type': 'artist',
#     'uri': 'spotify:artist:7B7TGqQe7QTVm2U6q8jzk1'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1bPxKZtCdjB1aj1csBJpdS'},
#     'followers': {'href': None, 'total': 23836},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1bPxKZtCdjB1aj1csBJpdS',
#     'id': '1bPxKZtCdjB1aj1csBJpdS',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/c3f33bf2d8bc3e00d0d82fd9e2a11c0594079833',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/6535600354e3ff225b5704ab3c9b4a4033746fb1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ba89cf9b97304f9f07132e8bb06293170109b64b',
#       'width': 64}],
#     'name': 'Lil Reese',
#     'popularity': 50,
#     'type': 'artist',
#     'uri': 'spotify:artist:1bPxKZtCdjB1aj1csBJpdS'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1grI9x4Uzos1Asx8JmRW6T'},
#     'followers': {'href': None, 'total': 18746},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1grI9x4Uzos1Asx8JmRW6T',
#     'id': '1grI9x4Uzos1Asx8JmRW6T',
#     'images': [{'height': 1024,
#       'url': 'https://i.scdn.co/image/3e53d37d29794eccb5fc9744b962df8f2c2b1725',
#       'width': 680},
#      {'height': 964,
#       'url': 'https://i.scdn.co/image/82bb674230d0b08e5c82e10dfe175759581e7800',
#       'width': 640},
#      {'height': 301,
#       'url': 'https://i.scdn.co/image/6f26c9f3aee5c6243f2abe210ab09446df90276b',
#       'width': 200},
#      {'height': 96,
#       'url': 'https://i.scdn.co/image/35fd540d7448475f46e06bc0b46f2ca106899910',
#       'width': 64}],
#     'name': 'Lil Keke',
#     'popularity': 48,
#     'type': 'artist',
#     'uri': 'spotify:artist:1grI9x4Uzos1Asx8JmRW6T'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7352aRY2mqSxBZwzUb6LmA'},
#     'followers': {'href': None, 'total': 118536},
#     'genres': ['hip pop', 'pop rap'],
#     'href': 'https://api.spotify.com/v1/artists/7352aRY2mqSxBZwzUb6LmA',
#     'id': '7352aRY2mqSxBZwzUb6LmA',
#     'images': [{'height': 1500,
#       'url': 'https://i.scdn.co/image/bbc23f477201e3784b54516ef2ad548794947277',
#       'width': 1000},
#      {'height': 960,
#       'url': 'https://i.scdn.co/image/4014b68d6e33d16883c70aab0972087d38e8896d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/5d3a1e94fb0fe5cf2dfb600cd7e55e8213025968',
#       'width': 200},
#      {'height': 96,
#       'url': 'https://i.scdn.co/image/6799537642674ef52cf0064aaef74cf04202c301',
#       'width': 64}],
#     'name': 'Bow Wow',
#     'popularity': 57,
#     'type': 'artist',
#     'uri': 'spotify:artist:7352aRY2mqSxBZwzUb6LmA'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5einkgXXrjhfYCyac1FANB'},
#     'followers': {'href': None, 'total': 27073},
#     'genres': ['crunk', 'dirty south rap', 'southern hip hop', 'trap music'],
#     'href': 'https://api.spotify.com/v1/artists/5einkgXXrjhfYCyac1FANB',
#     'id': '5einkgXXrjhfYCyac1FANB',
#     'images': [{'height': 300,
#       'url': 'https://i.scdn.co/image/722a084be153a03ca1bfb0c1e7c83bd4d37db156',
#       'width': 225},
#      {'height': 267,
#       'url': 'https://i.scdn.co/image/9c68dc0bb9b147bd31cb13a7b1e1d95acf481a90',
#       'width': 200},
#      {'height': 85,
#       'url': 'https://i.scdn.co/image/96df8040ad3c03f9471139786c4ea60f3998ca81',
#       'width': 64}],
#     'name': 'Lil Scrappy',
#     'popularity': 48,
#     'type': 'artist',
#     'uri': 'spotify:artist:5einkgXXrjhfYCyac1FANB'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/21O7WwRkik43ErKppxDKJq'},
#     'followers': {'href': None, 'total': 31101},
#     'genres': ['juggalo'],
#     'href': 'https://api.spotify.com/v1/artists/21O7WwRkik43ErKppxDKJq',
#     'id': '21O7WwRkik43ErKppxDKJq',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/01140761147a97db6a100c4456b531fb2d5aad82',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/0925d6476f14719b5ffd005fe0091e292c95e11e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/b232b4badce8651c11907c06ed6defcfc5616854',
#       'width': 64}],
#     'name': 'Lil Wyte',
#     'popularity': 50,
#     'type': 'artist',
#     'uri': 'spotify:artist:21O7WwRkik43ErKppxDKJq'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/74nSA5FdDOuuLw7Rn5JnuP'},
#     'followers': {'href': None, 'total': 5524},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/74nSA5FdDOuuLw7Rn5JnuP',
#     'id': '74nSA5FdDOuuLw7Rn5JnuP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/fc222056c3c65e02c96c3e94847a74ba7920757e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/052a2ef46226fa25801224fd676ba4abbb7da15a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/b3a4a57f6da39a5af2b2c56479819754caa51d35',
#       'width': 64}],
#     'name': 'Lil Blood',
#     'popularity': 45,
#     'type': 'artist',
#     'uri': 'spotify:artist:74nSA5FdDOuuLw7Rn5JnuP'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/42FaEHFfyxTdZQ5W28dXnj'},
#     'followers': {'href': None, 'total': 33976},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/42FaEHFfyxTdZQ5W28dXnj',
#     'id': '42FaEHFfyxTdZQ5W28dXnj',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/89c1a0ac4f8b95c843d633493bc3657a296e3e6b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/59654d32b34cfb51000ff26fec57ab36bf1781ae',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/b3afd3776d6e3e6ed82d45b4541e8623389e347b',
#       'width': 64}],
#     'name': 'Lil Snupe',
#     'popularity': 45,
#     'type': 'artist',
#     'uri': 'spotify:artist:42FaEHFfyxTdZQ5W28dXnj'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5qK5bOC6wLtuLhG5KvU17c'},
#     'followers': {'href': None, 'total': 21107},
#     'genres': ['hip pop'],
#     'href': 'https://api.spotify.com/v1/artists/5qK5bOC6wLtuLhG5KvU17c',
#     'id': '5qK5bOC6wLtuLhG5KvU17c',
#     'images': [{'height': 750,
#       'url': 'https://i.scdn.co/image/8e33c09ff1d5d91ea47254a389c36f626775275a',
#       'width': 600},
#      {'height': 250,
#       'url': 'https://i.scdn.co/image/991889a4147550d0421dfb80621c2e161ac7e043',
#       'width': 200},
#      {'height': 80,
#       'url': 'https://i.scdn.co/image/253d651a020406eb7c264304803463badabfe8cb',
#       'width': 64}],
#     'name': 'Lil Mama',
#     'popularity': 45,
#     'type': 'artist',
#     'uri': 'spotify:artist:5qK5bOC6wLtuLhG5KvU17c'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4dqh62yIzDBmrMeBOLiP5F'},
#     'followers': {'href': None, 'total': 224},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4dqh62yIzDBmrMeBOLiP5F',
#     'id': '4dqh62yIzDBmrMeBOLiP5F',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/5fbeb835c159b8de635ef8f5c6cc002ce138aec2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/3002b77643ae099b657a5eca5f99a79ca064b2f7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/73507e320c68d9890524a15f2eca9390a9fec455',
#       'width': 64}],
#     'name': 'Lil B',
#     'popularity': 44,
#     'type': 'artist',
#     'uri': 'spotify:artist:4dqh62yIzDBmrMeBOLiP5F'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5tth2a3v0sWwV1C7bApBdX'},
#     'followers': {'href': None, 'total': 70213},
#     'genres': ['hip pop'],
#     'href': 'https://api.spotify.com/v1/artists/5tth2a3v0sWwV1C7bApBdX',
#     'id': '5tth2a3v0sWwV1C7bApBdX',
#     'images': [{'height': 667,
#       'url': 'https://i.scdn.co/image/86a3e71ffa1706d337405150ec3bb7b4e246db7b',
#       'width': 1000},
#      {'height': 427,
#       'url': 'https://i.scdn.co/image/aa469a2c66d8e71308dbfb3efdb116be37ccdcaa',
#       'width': 640},
#      {'height': 133,
#       'url': 'https://i.scdn.co/image/a0e5359dc08b113b293b9d46715dea3ade289ba0',
#       'width': 200},
#      {'height': 43,
#       'url': 'https://i.scdn.co/image/74c219f600ec1d671430515820392104a64be811',
#       'width': 64}],
#     'name': "Lil' Kim",
#     'popularity': 62,
#     'type': 'artist',
#     'uri': 'spotify:artist:5tth2a3v0sWwV1C7bApBdX'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1I5u5Umau1AgHl0ZbPL1oR'},
#     'followers': {'href': None, 'total': 15573},
#     'genres': ['chicano rap'],
#     'href': 'https://api.spotify.com/v1/artists/1I5u5Umau1AgHl0ZbPL1oR',
#     'id': '1I5u5Umau1AgHl0ZbPL1oR',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/9a690f19d1f22f37c2d8ea2269d5d13c227059c7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/8a8413a32bf7407d8e3c7705fb24db7b817d7804',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/06ce7932e56c32475af8927bfffcce0d76475be8',
#       'width': 64}],
#     'name': 'Lil Cuete',
#     'popularity': 40,
#     'type': 'artist',
#     'uri': 'spotify:artist:1I5u5Umau1AgHl0ZbPL1oR'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3QnIBUOS4mUzs67rZ8r4c9'},
#     'followers': {'href': None, 'total': 5331},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3QnIBUOS4mUzs67rZ8r4c9',
#     'id': '3QnIBUOS4mUzs67rZ8r4c9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/e67d6752b4bc97f8e62e3bad2020d1a771543329',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/252344a7a2903b910fe462fb1d03e4050182d7ad',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/4481d09538ecb2554f01dec59f05dd050d1b03b9',
#       'width': 64}],
#     'name': 'Lil Phat',
#     'popularity': 39,
#     'type': 'artist',
#     'uri': 'spotify:artist:3QnIBUOS4mUzs67rZ8r4c9'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3FNZcjyqT7F5upP99JV0oN'},
#     'followers': {'href': None, 'total': 14521},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3FNZcjyqT7F5upP99JV0oN',
#     'id': '3FNZcjyqT7F5upP99JV0oN',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/f7a2070d4432472565f88e4d8e25f61de58bfde9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/97e0127d38fd5f0b2e9c5fd593a42148f26ee8c7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/c8c722d37914c9bd4f1b1af5b1c0e152e3e74c19',
#       'width': 64}],
#     'name': 'Lil Debbie',
#     'popularity': 43,
#     'type': 'artist',
#     'uri': 'spotify:artist:3FNZcjyqT7F5upP99JV0oN'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/564gvOqSRcQoYAhaBpTiK2'},
#     'followers': {'href': None, 'total': 14832},
#     'genres': ['jerk'],
#     'href': 'https://api.spotify.com/v1/artists/564gvOqSRcQoYAhaBpTiK2',
#     'id': '564gvOqSRcQoYAhaBpTiK2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/5280b8361231a8275ef9aeaa4e4d9a7701790eb5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/112c7e13cf136d3389ac4e2568af3cb1a02285b7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/0c0031c220e6536650161d837192c64168690d86',
#       'width': 64}],
#     'name': 'Lil Twist',
#     'popularity': 39,
#     'type': 'artist',
#     'uri': 'spotify:artist:564gvOqSRcQoYAhaBpTiK2'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5EQERGi7ffHvHsv3bnqzBn'},
#     'followers': {'href': None, 'total': 2123},
#     'genres': ['deep trap'],
#     'href': 'https://api.spotify.com/v1/artists/5EQERGi7ffHvHsv3bnqzBn',
#     'id': '5EQERGi7ffHvHsv3bnqzBn',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/b05aaee4b347f25bd1f190a47d2a04a30db96ee4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/7cc46db0ae9aca73de9ce788ffee37711af092db',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/e39030f343a1365761a1778a873a369573fb5e11',
#       'width': 64}],
#     'name': 'Lil Trill',
#     'popularity': 37,
#     'type': 'artist',
#     'uri': 'spotify:artist:5EQERGi7ffHvHsv3bnqzBn'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5YZZbPdI7P7te3lW3dTpzK'},
#     'followers': {'href': None, 'total': 318},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5YZZbPdI7P7te3lW3dTpzK',
#     'id': '5YZZbPdI7P7te3lW3dTpzK',
#     'images': [{'height': 960,
#       'url': 'https://i.scdn.co/image/171bcf1727e696bb7abe4af8c339654a03335c75',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/4fc43fb0bb59f30f92a4a61267b2d68a16441041',
#       'width': 200},
#      {'height': 96,
#       'url': 'https://i.scdn.co/image/13157eee5b9392e4c9eddced209e32eac2540000',
#       'width': 64}],
#     'name': 'Lil Twon',
#     'popularity': 38,
#     'type': 'artist',
#     'uri': 'spotify:artist:5YZZbPdI7P7te3lW3dTpzK'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2jXwYLNnCxNavms4mc1DYM'},
#     'followers': {'href': None, 'total': 897},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2jXwYLNnCxNavms4mc1DYM',
#     'id': '2jXwYLNnCxNavms4mc1DYM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/c836e08658864e66d993dd082d22d6dfee7d4645',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/255d752315107f40dc7ff7d9deff7955f6ca569e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/93902d4634605f54f6d16df88d4bd7bbf2b5ae4a',
#       'width': 64}],
#     'name': 'Lil AJ',
#     'popularity': 37,
#     'type': 'artist',
#     'uri': 'spotify:artist:2jXwYLNnCxNavms4mc1DYM'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6zSBkdKFLKKggDtE3amfCk'},
#     'followers': {'href': None, 'total': 1330},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6zSBkdKFLKKggDtE3amfCk',
#     'id': '6zSBkdKFLKKggDtE3amfCk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/5711c2a25c98d389ae955cb562dedcaca06a08d6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/bc2a5a16f5654aeae7edbc00cd4ae95499d1a561',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/1882daf793d5734228f415a9e9c3ac568326fa90',
#       'width': 64}],
#     'name': 'Lil Lonnie',
#     'popularity': 37,
#     'type': 'artist',
#     'uri': 'spotify:artist:6zSBkdKFLKKggDtE3amfCk'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1mmlWsyPJvvxMdabcGJjRn'},
#     'followers': {'href': None, 'total': 170},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1mmlWsyPJvvxMdabcGJjRn',
#     'id': '1mmlWsyPJvvxMdabcGJjRn',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/60159d868f6ceb3433cc4d9c6ad9d551c142a1ec',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/d84f042b1e6785cac700ead5797b250d0e00744d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/98efe8330240c282b4a87fd98bf90f8c93f869cc',
#       'width': 64}],
#     'name': 'Lil Boom',
#     'popularity': 35,
#     'type': 'artist',
#     'uri': 'spotify:artist:1mmlWsyPJvvxMdabcGJjRn'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3rWaFjgOi5mjQfllMfN3VI'},
#     'followers': {'href': None, 'total': 1340},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3rWaFjgOi5mjQfllMfN3VI',
#     'id': '3rWaFjgOi5mjQfllMfN3VI',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/27cd70424eb57712af1a3f02d8c065fb8248c6f7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/5df4c3e9982888cfc853591361bde30b26e4b182',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/cf681ac1c01f676cb8848fc3c1c1e91af4981940',
#       'width': 64}],
#     'name': 'Lil Goofy',
#     'popularity': 35,
#     'type': 'artist',
#     'uri': 'spotify:artist:3rWaFjgOi5mjQfllMfN3VI'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6tslWi0BXiDdtChermDzkU'},
#     'followers': {'href': None, 'total': 4743},
#     'genres': ['chicano rap'],
#     'href': 'https://api.spotify.com/v1/artists/6tslWi0BXiDdtChermDzkU',
#     'id': '6tslWi0BXiDdtChermDzkU',
#     'images': [{'height': 445,
#       'url': 'https://i.scdn.co/image/f3e380e2bb1706ccc3ff3136a5909b2df62fc8e6',
#       'width': 999},
#      {'height': 285,
#       'url': 'https://i.scdn.co/image/b422c3b95293beb367cf38901631d5537c6431b1',
#       'width': 640},
#      {'height': 89,
#       'url': 'https://i.scdn.co/image/c827b7877bde6b4295d708b75ec78bb493ad7245',
#       'width': 200},
#      {'height': 29,
#       'url': 'https://i.scdn.co/image/f9ee61c0fc0e027f2a87cb2a610637ebce8e8e4c',
#       'width': 64}],
#     'name': 'Mr. Lil One',
#     'popularity': 36,
#     'type': 'artist',
#     'uri': 'spotify:artist:6tslWi0BXiDdtChermDzkU'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4E9dumwOMLlTyXUp1i2WdI'},
#     'followers': {'href': None, 'total': 679},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4E9dumwOMLlTyXUp1i2WdI',
#     'id': '4E9dumwOMLlTyXUp1i2WdI',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/0248b931d044d7cd9e04e985dd60e262d47bd48e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/2e0750e4f4f1b6faef4694e8cdc7be2ea7943025',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/71627015b26cd42d2d4912b0b728d26d5aa021bc',
#       'width': 64}],
#     'name': 'Lil Haiti',
#     'popularity': 36,
#     'type': 'artist',
#     'uri': 'spotify:artist:4E9dumwOMLlTyXUp1i2WdI'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/069qBEK34YGoX7nSIT74Eg'},
#     'followers': {'href': None, 'total': 1763},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/069qBEK34YGoX7nSIT74Eg',
#     'id': '069qBEK34YGoX7nSIT74Eg',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/00f49af07547e77af2b67f621c8fd77be607f166',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/760852e9190609b0bf7bab4c5ba3fd14654956a3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/390f2cc02272310ae41fb67ef92b7bf226262be6',
#       'width': 64}],
#     'name': 'Lil Flash',
#     'popularity': 38,
#     'type': 'artist',
#     'uri': 'spotify:artist:069qBEK34YGoX7nSIT74Eg'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/38XiDu0kK3Z5jdHUDqBzNT'},
#     'followers': {'href': None, 'total': 1658},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/38XiDu0kK3Z5jdHUDqBzNT',
#     'id': '38XiDu0kK3Z5jdHUDqBzNT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/63f06a92ecd7974e1360c1fbf318285b52208594',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/2cc112871d0755a7b08c8640d77c027dbe2fefff',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/37245d0c87fc06fd2ed5aab80207c2a70b688e9d',
#       'width': 64}],
#     'name': 'Lil Kesh',
#     'popularity': 39,
#     'type': 'artist',
#     'uri': 'spotify:artist:38XiDu0kK3Z5jdHUDqBzNT'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/43BqexhEx5NKF7VfeOYP9m'},
#     'followers': {'href': None, 'total': 985},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/43BqexhEx5NKF7VfeOYP9m',
#     'id': '43BqexhEx5NKF7VfeOYP9m',
#     'images': [{'height': 500,
#       'url': 'https://i.scdn.co/image/19b3c85c69a68790f2edef06bd2da9e51ee88a44',
#       'width': 500},
#      {'height': 200,
#       'url': 'https://i.scdn.co/image/ced2056dc33e8b3c318560ecdc393c5e79939927',
#       'width': 200},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/08f5c3a7abf35edf216ce353f611b37d1251e2ca',
#       'width': 64}],
#     'name': 'Lil Cray',
#     'popularity': 35,
#     'type': 'artist',
#     'uri': 'spotify:artist:43BqexhEx5NKF7VfeOYP9m'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2Kv0ApBohrL213X9avMrEn'},
#     'followers': {'href': None, 'total': 9421},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2Kv0ApBohrL213X9avMrEn',
#     'id': '2Kv0ApBohrL213X9avMrEn',
#     'images': [{'height': 1500,
#       'url': 'https://i.scdn.co/image/9b1581aa35fa3461ad886fe8999f3757d3292fb7',
#       'width': 1000},
#      {'height': 960,
#       'url': 'https://i.scdn.co/image/7105c05c8533bf8689937a1d37613db9576b73d8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/79b367700f460ea27a3f0ad56ac2596d3f220ae1',
#       'width': 200},
#      {'height': 96,
#       'url': 'https://i.scdn.co/image/9bf3f51c3475fcfa7e2cac1780c97dff19cb47c4',
#       'width': 64}],
#     'name': 'Lil Silva',
#     'popularity': 43,
#     'type': 'artist',
#     'uri': 'spotify:artist:2Kv0ApBohrL213X9avMrEn'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4IFVaKBbEO8Qkurg6nmoc4'},
#     'followers': {'href': None, 'total': 3286},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4IFVaKBbEO8Qkurg6nmoc4',
#     'id': '4IFVaKBbEO8Qkurg6nmoc4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/a71e6d63cee27fbf8d35783319f27517544729a6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/6872135b1c7727339bc927f76b6502e7b0626bb4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/b9704a6bad87cf9e221824ac02f09dc8569c5fc6',
#       'width': 64}],
#     'name': 'Lil Rue',
#     'popularity': 34,
#     'type': 'artist',
#     'uri': 'spotify:artist:4IFVaKBbEO8Qkurg6nmoc4'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5CY0QKsbUBpQJIE2yycsYi'},
#     'followers': {'href': None, 'total': 1623},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5CY0QKsbUBpQJIE2yycsYi',
#     'id': '5CY0QKsbUBpQJIE2yycsYi',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/a1ab38ca89a4640ba1306c5f2ade50750194e5d9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/5ba8136190e12f51a128855f107afcfd446e63bd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/b2c57e0ba16bb50a92e84a1776bc6a324d858c2c',
#       'width': 64}],
#     'name': 'Lil Eddie',
#     'popularity': 41,
#     'type': 'artist',
#     'uri': 'spotify:artist:5CY0QKsbUBpQJIE2yycsYi'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4vIlHBnzWKbmWe8ZOkT1ZT'},
#     'followers': {'href': None, 'total': 1129},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4vIlHBnzWKbmWe8ZOkT1ZT',
#     'id': '4vIlHBnzWKbmWe8ZOkT1ZT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/0f0c996d27335179f4136620e95d9c3245147806',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/923c54f357bb8fbba8623cadb9f4194e90de760c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/85d4cf1f11ec3ba3481a9414fbb5dc5801abe086',
#       'width': 64}],
#     'name': 'Lil Yase',
#     'popularity': 33,
#     'type': 'artist',
#     'uri': 'spotify:artist:4vIlHBnzWKbmWe8ZOkT1ZT'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/65npPa1U4cgobX9wU7Jgpb'},
#     'followers': {'href': None, 'total': 12848},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/65npPa1U4cgobX9wU7Jgpb',
#     'id': '65npPa1U4cgobX9wU7Jgpb',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/97bfe3f9251d35d9a358d8e937d3a6365c7a674a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/201eee225cd733022b0e78f6fbfe04861d898a84',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/80f03593b486eb3b70f9c035097d669e7704c328',
#       'width': 64}],
#     'name': 'Lil Wayne, DJ Drama',
#     'popularity': 35,
#     'type': 'artist',
#     'uri': 'spotify:artist:65npPa1U4cgobX9wU7Jgpb'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5HPsVk1MblCoa44WLJsQwN'},
#     'followers': {'href': None, 'total': 5889},
#     'genres': ['freestyle'],
#     'href': 'https://api.spotify.com/v1/artists/5HPsVk1MblCoa44WLJsQwN',
#     'id': '5HPsVk1MblCoa44WLJsQwN',
#     'images': [{'height': 482,
#       'url': 'https://i.scdn.co/image/9e2c6bb7420bdfe0675255200e6a90fbe6744514',
#       'width': 720},
#      {'height': 428,
#       'url': 'https://i.scdn.co/image/861aeb62673db5c88a4938462051496d54a88e14',
#       'width': 639},
#      {'height': 134,
#       'url': 'https://i.scdn.co/image/3bcf3420690356d33c72e6d699a6e087a2f287d4',
#       'width': 200},
#      {'height': 43,
#       'url': 'https://i.scdn.co/image/b807785791281b511ee7e545825f5508648914b0',
#       'width': 64}],
#     'name': 'Lil Suzy',
#     'popularity': 34,
#     'type': 'artist',
#     'uri': 'spotify:artist:5HPsVk1MblCoa44WLJsQwN'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1cEHxCgGlEgqBc91YOcAEQ'},
#     'followers': {'href': None, 'total': 16302},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1cEHxCgGlEgqBc91YOcAEQ',
#     'id': '1cEHxCgGlEgqBc91YOcAEQ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/a7969adf46dff0c450120388bef4e760e2443a66',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/9f155a53e2c7be92a0846befc94162e84a5e02b9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/7b434e7ce5acc91a1f1df22a4af376281e98dbbe',
#       'width': 64}],
#     'name': 'Lil Mouse',
#     'popularity': 34,
#     'type': 'artist',
#     'uri': 'spotify:artist:1cEHxCgGlEgqBc91YOcAEQ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/69swdLSkKxCQBMYJ55O2mA'},
#     'followers': {'href': None, 'total': 1705},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/69swdLSkKxCQBMYJ55O2mA',
#     'id': '69swdLSkKxCQBMYJ55O2mA',
#     'images': [{'height': 300,
#       'url': 'https://i.scdn.co/image/0b0c4aa534c6203577fd01f13a00807e4635851c',
#       'width': 200},
#      {'height': 96,
#       'url': 'https://i.scdn.co/image/ddef4f63a39e9007bef9adab285e7c51ce345848',
#       'width': 64}],
#     'name': 'Lil C',
#     'popularity': 33,
#     'type': 'artist',
#     'uri': 'spotify:artist:69swdLSkKxCQBMYJ55O2mA'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1qKzKUnuQsjB83hBZffoq0'},
#     'followers': {'href': None, 'total': 1828},
#     'genres': ['soca'],
#     'href': 'https://api.spotify.com/v1/artists/1qKzKUnuQsjB83hBZffoq0',
#     'id': '1qKzKUnuQsjB83hBZffoq0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/4008de208a4462c926c09d5d341638abaa734d9d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/bd35dfb47d9719d7c94d185b55364a63d9a6e37d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/5d11e2608b6c526ae1bc76a09b0357ac3d802bfe',
#       'width': 64}],
#     'name': 'Lil Rick',
#     'popularity': 39,
#     'type': 'artist',
#     'uri': 'spotify:artist:1qKzKUnuQsjB83hBZffoq0'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3GH3KD2078kLPpEkN1UN26'},
#     'followers': {'href': None, 'total': 1396},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3GH3KD2078kLPpEkN1UN26',
#     'id': '3GH3KD2078kLPpEkN1UN26',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/076a261d997d38ebbb55041a67bd4e00d960ce7e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/fbfc9a3a04437bba987ff1c2f4f38358b809b155',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/0b3c65e61d127766aa052b33bcddd796d06d0f28',
#       'width': 64}],
#     'name': 'Lil June',
#     'popularity': 32,
#     'type': 'artist',
#     'uri': 'spotify:artist:3GH3KD2078kLPpEkN1UN26'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0zn6yzsbWj3EPMgOTqfG5k'},
#     'followers': {'href': None, 'total': 130},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/0zn6yzsbWj3EPMgOTqfG5k',
#     'id': '0zn6yzsbWj3EPMgOTqfG5k',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/35638d3cfbc1b763aeb111c9273e724bdef12aa4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ecd0a4a293cd661df2a8da127c343c46d4f7d11e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/a9d06155df08da255a54a8dc598961b5ff5a3958',
#       'width': 64}],
#     'name': 'Lil E',
#     'popularity': 34,
#     'type': 'artist',
#     'uri': 'spotify:artist:0zn6yzsbWj3EPMgOTqfG5k'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6JUnsP7jmvYmdhbg7lTMQj'},
#     'followers': {'href': None, 'total': 110},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6JUnsP7jmvYmdhbg7lTMQj',
#     'id': '6JUnsP7jmvYmdhbg7lTMQj',
#     'images': [],
#     'name': 'Lil Fate',
#     'popularity': 34,
#     'type': 'artist',
#     'uri': 'spotify:artist:6JUnsP7jmvYmdhbg7lTMQj'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Q5sPmM8j4SpMqL4UA1DtS'},
#     'followers': {'href': None, 'total': 19887},
#     'genres': ['crunk', 'dirty south rap'],
#     'href': 'https://api.spotify.com/v1/artists/4Q5sPmM8j4SpMqL4UA1DtS',
#     'id': '4Q5sPmM8j4SpMqL4UA1DtS',
#     'images': [{'height': 810,
#       'url': 'https://i.scdn.co/image/3767913038db1bbb8e971a3f93b4eb2c86b402c1',
#       'width': 1000},
#      {'height': 519,
#       'url': 'https://i.scdn.co/image/dcc17914d52f5194f21ed73c2272701f940be220',
#       'width': 640},
#      {'height': 162,
#       'url': 'https://i.scdn.co/image/a645742d2b72d97d0abeb35eb880439f11013b1d',
#       'width': 200},
#      {'height': 52,
#       'url': 'https://i.scdn.co/image/d2f390e207477cdd0e2229429593f7dd99f08e54',
#       'width': 64}],
#     'name': "Lil' Flip",
#     'popularity': 49,
#     'type': 'artist',
#     'uri': 'spotify:artist:4Q5sPmM8j4SpMqL4UA1DtS'}],
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/search?query=Lil&offset=50&limit=50&type=artist',
#   'offset': 0,
#   'previous': None,
#   'total': 4502}}

# %%
Lil_artists = Lil_data['artists']['items']
#Print a list of Lil's that are more popular than Lil' Kim.
for artist in Lil_artists:
    if artist['popularity'] > 62:
        print(artist['name'],"has the popularity of", artist['popularity'])
# Out:
# Lil Wayne has the popularity of 86
# Lil Yachty has the popularity of 72
# Lil Uzi Vert has the popularity of 72
# Lil Dicky has the popularity of 68
# Boosie Badazz has the popularity of 67
# Lil Jon has the popularity of 72

# %%
#Pick two of your favorite Lils to fight it out, and use their IDs to print out their top tracks.
#Tip: You're going to be making two separate requests, be sure you DO NOT save them into the same variable.
response = requests.get("https://api.spotify.com/v1/artists/55Aa2cqylxrFIXC767Z865/top-tracks?country=US")
data = response.json()
tracks = data['tracks']
print("Lil Wayne's top tracks are: ")
for track in tracks:
    print("-", track['name'])
print("-----------------------------------------------")

response = requests.get("https://api.spotify.com/v1/artists/6icQOAFXDZKsumw3YXyusw/top-tracks?country=US")
data = response.json()
tracks = data['tracks']
print("Lil Yachty 's top tracks are: ")
for track in tracks:
    print("-", track['name'])
# Out:
# Lil Wayne's top tracks are:
# - Forever
# - Nothing But Trouble - Instagram Models
# - 6 Foot 7 Foot
# - A Milli
# - Right Above It
# - Lollipop
# - Love Me
# - Rich As Fuck
# - Mirror
# - Believe Me
# -----------------------------------------------
# Lil Yachty 's top tracks are:
# - One Night (Extended)
# - Minnesota (Remix) [feat. Quavo, Skippa da Flippa & Young Thug]
# - Wanna Be Us (feat. Burberry Perry)
# - Intro (Just Keep Swimming)
# - Up Next 2 (feat. Big Brutha Chubba & Byou)
# - Good Day (feat. Skippa da Flippa)
# - Not My Bro
# - Fucked Over
# - Out Late
# - Interlude

# %%
response = requests.get("https://api.spotify.com/v1/search?query=Lil&type=artist&limit=2&country=US")
data = response.json()
for artist in Lil_artists:
    print(artist['name'],artist['id'])
# Out:
# Lil Wayne 55Aa2cqylxrFIXC767Z865
# Lil Yachty 6icQOAFXDZKsumw3YXyusw
# Lil Uzi Vert 4O15NlyKLIASxsJ0PrXPfz
# Lil Dicky 1tqhsYv8yBBdwANFNzHtcr
# Boosie Badazz 6z7xFFHxYkE9t8bwIF0Bvg
# Lil Jon 7sfl4Xt5KmfyDs2T3SVSMK
# King Lil G 6L3x3if9RVimruryD9LoFb
# Lil Durk 3hcs9uc56yIGFCSy9leWe7
# Lil Jon & The East Side Boyz 3ciRvbBIVz9fBoPbtSYq4x
# Lil Bibby 4uSN8Y3kgFNVULUWsZEAVW
# G Herbo 5QdEbQJ3ylBnc3gsIASAT5
# Lil Rob 7B7TGqQe7QTVm2U6q8jzk1
# Lil Reese 1bPxKZtCdjB1aj1csBJpdS
# Lil Keke 1grI9x4Uzos1Asx8JmRW6T
# Bow Wow 7352aRY2mqSxBZwzUb6LmA
# Lil Scrappy 5einkgXXrjhfYCyac1FANB
# Lil Wyte 21O7WwRkik43ErKppxDKJq
# Lil Blood 74nSA5FdDOuuLw7Rn5JnuP
# Lil Snupe 42FaEHFfyxTdZQ5W28dXnj
# Lil Mama 5qK5bOC6wLtuLhG5KvU17c
# Lil B 4dqh62yIzDBmrMeBOLiP5F
# Lil' Kim 5tth2a3v0sWwV1C7bApBdX
# Lil Cuete 1I5u5Umau1AgHl0ZbPL1oR
# Lil Phat 3QnIBUOS4mUzs67rZ8r4c9
# Lil Debbie 3FNZcjyqT7F5upP99JV0oN
# Lil Twist 564gvOqSRcQoYAhaBpTiK2
# Lil Trill 5EQERGi7ffHvHsv3bnqzBn
# Lil Twon 5YZZbPdI7P7te3lW3dTpzK
# Lil AJ 2jXwYLNnCxNavms4mc1DYM
# Lil Lonnie 6zSBkdKFLKKggDtE3amfCk
# Lil Boom 1mmlWsyPJvvxMdabcGJjRn
# Lil Goofy 3rWaFjgOi5mjQfllMfN3VI
# Mr. Lil One 6tslWi0BXiDdtChermDzkU
# Lil Haiti 4E9dumwOMLlTyXUp1i2WdI
# Lil Flash 069qBEK34YGoX7nSIT74Eg
# Lil Kesh 38XiDu0kK3Z5jdHUDqBzNT
# Lil Cray 43BqexhEx5NKF7VfeOYP9m
# Lil Silva 2Kv0ApBohrL213X9avMrEn
# Lil Rue 4IFVaKBbEO8Qkurg6nmoc4
# Lil Eddie 5CY0QKsbUBpQJIE2yycsYi
# Lil Yase 4vIlHBnzWKbmWe8ZOkT1ZT
# Lil Wayne, DJ Drama 65npPa1U4cgobX9wU7Jgpb
# Lil Suzy 5HPsVk1MblCoa44WLJsQwN
# Lil Mouse 1cEHxCgGlEgqBc91YOcAEQ
# Lil C 69swdLSkKxCQBMYJ55O2mA
# Lil Rick 1qKzKUnuQsjB83hBZffoq0
# Lil June 3GH3KD2078kLPpEkN1UN26
# Lil E 0zn6yzsbWj3EPMgOTqfG5k
# Lil Fate 6JUnsP7jmvYmdhbg7lTMQj
# Lil' Flip 4Q5sPmM8j4SpMqL4UA1DtS

# %%
artist_id = "55Aa2cqylxrFIXC767Z865"

# %%
#Get an average popularity for their explicit songs vs. their non-explicit songs. 
#How many minutes of explicit songs do they have? Non-explicit?
# How explicit is Lils?

response = requests.get("https://api.spotify.com/v1/artists/" + artist_id + "/top-tracks?country=US")
data = response.json()

# counter for tracks for explicit and clean
track_count = 0 
clean_count = 0
#counter to find avg popularity
popular_exp = 0
popular_clean = 0
#counter for avg time in minutes are below:
timer = 0
data_timer = 0
timer_clean = 0

for track in tracks:
    print("The track,", track['name'],", with the id",track['id'], "is", track['explicit'],"for explicit content, and has the popularity of", track['popularity'])
    track_id = track['id']
    time_ms = data_track['duration_ms']
    if True:
        track_count = track_count + 1
        popular_exp = popular_exp + track['popularity']
        response = requests.get("https://api.spotify.com/v1/tracks/" + track_id)
        data_track = response.json()
        print("and has the duration of", data_track['duration_ms'], "milli seconds.")
        timer = timer + time_ms
        timer_minutes = ((timer / (1000*60)) % 60)
    if not track['explicit']:
        clean_count = clean_count + 1
        popular_clean = popular_clean + track['popularity']
        response = requests.get("https://api.spotify.com/v1/tracks/" + track_id)
        data_tracks = response.json()
        timer_clean = timer_clean + time_ms
        timer_minutes_clean = ((data_timer / (1000*60)) % 60)
        print(", and has the duration of", timer_minutes_clean, "minutes")
        
print("------------------------------------")
avg_pop =  popular_exp / track_count
print("I have found", track_count, "tracks, and has the average popularity of", avg_pop, "and has the average duration of", timer_minutes,"minutes and", clean_count, "are clean")

#print("Overall, I discovered", track_count, "tracks")
#print("And", clean_count, "were non-explicit")
#print("Which means", , " percent were clean for Lil Wayne")
# Out:
# The track, One Night (Extended) , with the id 0l4EfZzVD0LyJhibHIIVxo is True for explicit content, and has the popularity of 77
# and has the duration of 243269 milli seconds.
# The track, Minnesota (Remix) [feat. Quavo, Skippa da Flippa & Young Thug] , with the id 7dTJQN1w1M79haPESIZ3zr is True for explicit content, and has the popularity of 68
# and has the duration of 268114 milli seconds.
# The track, Wanna Be Us (feat. Burberry Perry) , with the id 5xi6EyeIvVr6cCg44OZeEl is True for explicit content, and has the popularity of 63
# and has the duration of 171899 milli seconds.
# The track, Intro (Just Keep Swimming) , with the id 0cBD9mCJ3gFVNJdW2orLhz is True for explicit content, and has the popularity of 59
# and has the duration of 252369 milli seconds.
# The track, Up Next 2 (feat. Big Brutha Chubba & Byou) , with the id 2aJnTtI2KlV7Owx7tA63s8 is True for explicit content, and has the popularity of 57
# and has the duration of 178046 milli seconds.
# The track, Good Day (feat. Skippa da Flippa) , with the id 2e3oiurGwx1ueG0e18dGW6 is True for explicit content, and has the popularity of 56
# and has the duration of 198092 milli seconds.
# The track, Not My Bro , with the id 6K80Xw3GOaKguaHM0bQAzx is True for explicit content, and has the popularity of 56
# and has the duration of 143598 milli seconds.
# The track, Fucked Over , with the id 6U5OUBzrgftbUx1kVM4fH8 is True for explicit content, and has the popularity of 55
# and has the duration of 175262 milli seconds.
# The track, Out Late , with the id 3HIr5rowFdybrJxukOXlS5 is True for explicit content, and has the popularity of 55
# and has the duration of 160037 milli seconds.
# The track, Interlude , with the id 27dNwrgG4GoJrhloMrJMJJ is True for explicit content, and has the popularity of 55
# and has the duration of 78915 milli seconds.
# ------------------------------------
# I have found 10 tracks, and has the average popularity of 60.1 and has the average duration of 31.160016666666667 minutes and 0 are clean

# %%
artist2_id = "6icQOAFXDZKsumw3YXyusw"

# %%
#Get an average popularity for their explicit songs vs. their non-explicit songs. 
#How many minutes of explicit songs do they have? Non-explicit?
# How explicit is Lils?

response = requests.get("https://api.spotify.com/v1/artists/" + artist_id + "/top-tracks?country=US")
data = response.json()
# counter for tracks for explicit and clean
track_count = 0 
clean_count = 0
#counter to find avg popularity
popular_exp = 0
popular_clean = 0
#counter for avg time in minutes are below:
timer = 0
#data_timer = 0
timer_clean = 0

for track in tracks:
    print("The track,", track['name'],", with the id",track['id'], "is", track['explicit'],"for explicit content, and has the popularity of", track['popularity'])
    track_id = track['id']
    time_ms = data_track['duration_ms']
    if True:
        track_count = track_count + 1
        popular_exp = popular_exp + track['popularity']
        response = requests.get("https://api.spotify.com/v1/tracks/" + track_id)
        data_track = response.json()
        print("and has the duration of", data_track['duration_ms'], "milli seconds.")
        timer = timer + time_ms
        timer_minutes = ((timer / (1000*60)) % 60)
    if not track['explicit']:
        clean_count = clean_count + 1
        popular_clean = popular_clean + track['popularity']
        response = requests.get("https://api.spotify.com/v1/tracks/" + track_id)
        data_tracks = response.json()
        timer_clean = timer_clean + time_ms
        timer_minutes_clean = ((data_timer / (1000*60)) % 60)
        print(", and has the duration of", timer_minutes_clean, "minutes")
        
print("------------------------------------")
avg_pop =  popular_exp / track_count
print("I have found", track_count, "tracks, and has the average popularity of", avg_pop, "and has the average duration of", timer_minutes,"minutes and", clean_count, "are clean")

#print("Overall, I discovered", track_count, "tracks")
#print("And", clean_count, "were non-explicit")
#print("Which means", , " percent were clean for Lil Wayne")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-b3d7f5664797> in <module>()
#      16 timer_clean = 0
#      17
# ---> 18 for track in tracks:
#      19     print("The track,", track['name'],", with the id",track['id'], "is", track['explicit'],"for explicit content, and has the popularity of", track['popularity'])
#      20     track_id = track['id']
#
# NameError: name 'tracks' is not defined

# %%
#How many total "Biggie" artists are there? How many total "Lil"s? 
#If you made 1 request every 5 seconds, how long would it take to download information on all the Lils vs the Biggies?

biggie_response = requests.get('https://api.spotify.com/v1/search?query=biggie&type=artist&limit=50&country=US')
biggie_data = biggie_response.json()
biggie_artists = biggie_data['artists']['total']
print("Total number of Biggie artists are", biggie_artists)

lil_response = requests.get('https://api.spotify.com/v1/search?query=Lil&type=artist&limit=50&country=US')
lil_data = lil_response.json()
lil_artists = lil_data['artists']['total']
print("Total number of Lil artists are", lil_artists)
# Out:
# Total number of Biggie artists are 49
# Total number of Lil artists are 4501

# %%
#If you made 1 request every 5 seconds, how long would it take to download information on all the Lils vs the Biggies?

limit_download = 50
biggie_artists = biggie_data['artists']['total']
Lil_artist = Lil_data['artists']['total']

#1n 5 sec = 50
#in 1 sec = 50 / 5 req = 10 no, for 1 no, 1/10 sec
# for 4501 = 4501/10 sec
# for 49 49/ 10 sec

big_count = biggie_artists/10
lil_count = Lil_artist / 10

print("It would take", big_count, "seconds for Biggies, where as it would take", lil_count,"seconds for Lils" )
# Out:
# It would take 4.9 seconds for Biggies, where as it would take 450.1 seconds for Lils

# %%
#Out of the top 50 "Lil"s and the top 50 "Biggie"s, who is more popular on average?

biggie_response = requests.get('https://api.spotify.com/v1/search?query=biggie&type=artist&limit=50&country=US')
biggie_data = biggie_response.json()

biggie_artists = biggie_data['artists']['items']
big_count_pop = 0
for artist in biggie_artists:
    #count_pop = artist['popularity']
    big_count_pop = big_count_pop + artist['popularity']
print("Biggie has a total popularity of ", big_count_pop)
big_pop = big_count_pop / 49
print("Biggie is on an average", big_pop,"popular")

#Lil
Lil_response = requests.get('https://api.spotify.com/v1/search?query=Lil&type=artist&limit=50&country=US')
Lil_data = Lil_response.json()
Lil_artists = Lil_data['artists']['items']
lil_count_pop = 0
for artist in Lil_artists:
    count_pop_lil = artist['popularity']
    lil_count_pop = lil_count_pop + count_pop_lil
lil_pop = lil_count_pop / 50
print("Lil is on an average", lil_pop,"popular")
# Out:
# Biggie has a total popularity of  193
# Biggie is on an average 3.938775510204082 popular
# Lil is on an average 46.16 popular

# %%
import requests

# %%
response = requests.get('http://api.nytimes.com/svc/books/v2/lists/2010-05-09/hardcover-fiction.json?api-key=3880684abea14d86b6280c6dbd80a793')
data = response.json()
print(data)
# Out:
# {'status': 'OK', 'copyright': 'Copyright (c) 2016 The New York Times Company.  All Rights Reserved.', 'last_modified': '2016-04-28T09:06:07-04:00', 'num_results': 35, 'results': [{'list_image': '9780446564076.jpg', 'asterisk': 0, 'list_image_width': 279, 'rank': 1, 'list_image_height': 500, 'list_name': 'Hardcover Fiction', 'normal_list_ends_at': 16, 'isbns': [{'isbn13': '9780446564076', 'isbn10': '0446564079'}, {'isbn13': '9780446576253', 'isbn10': '0446576255'}, {'isbn13': '9780892962617', 'isbn10': '0892962615'}, {'isbn13': '9780446564083', 'isbn10': '0446564087'}], 'display_name': 'Hardcover Fiction', 'book_details': [{'title': 'DELIVER US FROM EVIL', 'price': 27.99, 'contributor_note': '', 'age_group': '', 'primary_isbn13': '9780446564083', 'author': 'David Baldacci', 'description': 'Two agents are tracking the same man, a human trafficker who is now dealing in nuclear arms.', 'publisher': 'Grand Central', 'contributor': 'by David Baldacci', 'book_image': 'https://s1.nyt.com/du/books/images/9780446564076.jpg', 'primary_isbn10': '0446564087', 'amazon_product_url': 'http://www.amazon.com/Deliver-Us-Evil-David-Baldacci/dp/0446564079?tag=thenewyorktim-20'}], 'rank_last_week': 0, 'weeks_on_list': 1, 'bestsellers_date': '2010-04-25', 'list_name_encoded': 'hardcover-fiction', 'updated': 'WEEKLY', 'dagger': 0, 'reviews': [{'article_chapter_link': '', 'book_review_link': '', 'sunday_review_link': '', 'first_chapter_link': ''}], 'published_date_range': '2008-06-08:2016-06-12', 'published_date': '2010-05-09'}, {'list_image': '9780446564076.jpg', 'asterisk': 0, 'list_image_width': 279, 'rank': 2, 'list_image_height': 500, 'list_name': 'Hardcover Fiction', 'normal_list_ends_at': 16, 'isbns': [{'isbn13': '9780399155345', 'isbn10': '0399155341'}, {'isbn13': '9781440697661', 'isbn10': '1440697663'}, {'isbn13': '9780425232200', 'isbn10': '0425232204'}, {'isbn13': '9781594133886', 'isbn10': '1594133883'}, {'isbn13': '9780425245132', 'isbn10': '0425245136'}, {'isbn13': '9780399157912', 'isbn10': '0399157913'}], 'display_name': 'Hardcover Fiction', 'book_details': [{'title': 'THE HELP', 'price': 24.95, 'contributor_note': '', 'age_group': '', 'primary_isbn13': '9780399155345', 'author': 'Kathryn Stockett', 'description': 'A young white woman and two black maids in 1960s \xadMississippi.', 'publisher': 'Amy Einhorn/Putnam', 'contributor': 'by Kathryn Stockett', 'book_image': 'https://s1.nyt.com/du/books/images/9781440697661.jpg', 'primary_isbn10': '0399155341', 'amazon_product_url': 'http://www.amazon.com/The-Help-Kathryn-Stockett/dp/0425232204?tag=thenewyorktim-20'}], 'rank_last_week': 2, 'weeks_on_list': 56, 'bestsellers_date': '2010-04-25', 'list_name_encoded': 'hardcover-fiction', 'updated': 'WEEKLY', 'dagger': 0, 'reviews': [{'article_chapter_link': 'http://www.nytimes.com/2011/08/14/movies/black-and-white-struggle-through-hollywoods-rosy-glow.html', 'book_review_link': 'http://www.nytimes.com/2009/02/19/books/19masl.html', 'sunday_review_link': '', 'first_chapter_link': ''}], 'published_date_range': '2008-06-08:2016-06-12', 'published_date': '2010-05-09'}, {'list_image': '9780446564076.jpg', 'asterisk': 0, 'list_image_width': 279, 'rank': 3, 'list_image_height': 500, 'list_name': 'Hardcover Fiction', 'normal_list_ends_at': 16, 'isbns': [{'isbn13': '9780375424502', 'isbn10': '0375424504'}, {'isbn13': '9780307277480', 'isbn10': '0307277488'}], 'display_name': 'Hardcover Fiction', 'book_details': [{'title': 'THE DOUBLE COMFORT SAFARI CLUB', 'price': 24.95, 'contributor_note': '', 'age_group': '', 'primary_isbn13': '9780375424502', 'author': 'Alexander McCall Smith', 'description': '\nThe 11th novel in the No. 1 Ladies’ Detective Agency series.', 'publisher': 'Pantheon', 'contributor': 'by Alexander McCall Smith', 'book_image': 'https://s1.nyt.com/du/books/images/9780307277480.jpg', 'primary_isbn10': '0375424504', 'amazon_product_url': 'http://www.amazon.com/Double-Comfort-Safari-Ladies-Detective/dp/0375424504?tag=thenewyorktim-20'}], 'rank ...

# %%
print(data.keys())
# Out:
# dict_keys(['status', 'copyright', 'last_modified', 'num_results', 'results'])

# %%
print(data['results'])
# Out:
# [{'list_image': '9780446564076.jpg', 'asterisk': 0, 'list_image_width': 279, 'rank': 1, 'list_image_height': 500, 'list_name': 'Hardcover Fiction', 'normal_list_ends_at': 16, 'isbns': [{'isbn13': '9780446564076', 'isbn10': '0446564079'}, {'isbn13': '9780446576253', 'isbn10': '0446576255'}, {'isbn13': '9780892962617', 'isbn10': '0892962615'}, {'isbn13': '9780446564083', 'isbn10': '0446564087'}], 'display_name': 'Hardcover Fiction', 'book_details': [{'title': 'DELIVER US FROM EVIL', 'price': 27.99, 'contributor_note': '', 'age_group': '', 'primary_isbn13': '9780446564083', 'author': 'David Baldacci', 'description': 'Two agents are tracking the same man, a human trafficker who is now dealing in nuclear arms.', 'publisher': 'Grand Central', 'contributor': 'by David Baldacci', 'book_image': 'https://s1.nyt.com/du/books/images/9780446564076.jpg', 'primary_isbn10': '0446564087', 'amazon_product_url': 'http://www.amazon.com/Deliver-Us-Evil-David-Baldacci/dp/0446564079?tag=thenewyorktim-20'}], 'rank_last_week': 0, 'weeks_on_list': 1, 'bestsellers_date': '2010-04-25', 'list_name_encoded': 'hardcover-fiction', 'updated': 'WEEKLY', 'dagger': 0, 'reviews': [{'article_chapter_link': '', 'book_review_link': '', 'sunday_review_link': '', 'first_chapter_link': ''}], 'published_date_range': '2008-06-08:2016-06-12', 'published_date': '2010-05-09'}, {'list_image': '9780446564076.jpg', 'asterisk': 0, 'list_image_width': 279, 'rank': 2, 'list_image_height': 500, 'list_name': 'Hardcover Fiction', 'normal_list_ends_at': 16, 'isbns': [{'isbn13': '9780399155345', 'isbn10': '0399155341'}, {'isbn13': '9781440697661', 'isbn10': '1440697663'}, {'isbn13': '9780425232200', 'isbn10': '0425232204'}, {'isbn13': '9781594133886', 'isbn10': '1594133883'}, {'isbn13': '9780425245132', 'isbn10': '0425245136'}, {'isbn13': '9780399157912', 'isbn10': '0399157913'}], 'display_name': 'Hardcover Fiction', 'book_details': [{'title': 'THE HELP', 'price': 24.95, 'contributor_note': '', 'age_group': '', 'primary_isbn13': '9780399155345', 'author': 'Kathryn Stockett', 'description': 'A young white woman and two black maids in 1960s \xadMississippi.', 'publisher': 'Amy Einhorn/Putnam', 'contributor': 'by Kathryn Stockett', 'book_image': 'https://s1.nyt.com/du/books/images/9781440697661.jpg', 'primary_isbn10': '0399155341', 'amazon_product_url': 'http://www.amazon.com/The-Help-Kathryn-Stockett/dp/0425232204?tag=thenewyorktim-20'}], 'rank_last_week': 2, 'weeks_on_list': 56, 'bestsellers_date': '2010-04-25', 'list_name_encoded': 'hardcover-fiction', 'updated': 'WEEKLY', 'dagger': 0, 'reviews': [{'article_chapter_link': 'http://www.nytimes.com/2011/08/14/movies/black-and-white-struggle-through-hollywoods-rosy-glow.html', 'book_review_link': 'http://www.nytimes.com/2009/02/19/books/19masl.html', 'sunday_review_link': '', 'first_chapter_link': ''}], 'published_date_range': '2008-06-08:2016-06-12', 'published_date': '2010-05-09'}, {'list_image': '9780446564076.jpg', 'asterisk': 0, 'list_image_width': 279, 'rank': 3, 'list_image_height': 500, 'list_name': 'Hardcover Fiction', 'normal_list_ends_at': 16, 'isbns': [{'isbn13': '9780375424502', 'isbn10': '0375424504'}, {'isbn13': '9780307277480', 'isbn10': '0307277488'}], 'display_name': 'Hardcover Fiction', 'book_details': [{'title': 'THE DOUBLE COMFORT SAFARI CLUB', 'price': 24.95, 'contributor_note': '', 'age_group': '', 'primary_isbn13': '9780375424502', 'author': 'Alexander McCall Smith', 'description': '\nThe 11th novel in the No. 1 Ladies’ Detective Agency series.', 'publisher': 'Pantheon', 'contributor': 'by Alexander McCall Smith', 'book_image': 'https://s1.nyt.com/du/books/images/9780307277480.jpg', 'primary_isbn10': '0375424504', 'amazon_product_url': 'http://www.amazon.com/Double-Comfort-Safari-Ladies-Detective/dp/0375424504?tag=thenewyorktim-20'}], 'rank_last_week': 0, 'weeks_on_list': 1, 'bestsellers_date': '2010-04-25', 'list_name_encoded': 'hardcover-fiction', 'updated': 'WEEKLY', 'dagger': 0, 'reviews': [{'article_chapter_li ...

# %%
#What books topped the Hardcover Fiction NYT best-sellers list on Mother's Day in 2009 and 2010? How about Father's Day?
#mothers day in 2010
book_result = data['results']

#print(book_result)

for i in book_result:
    #print(i['book_details'])
    for item in i['book_details']:
        print(item['title'])
# Out:
# DELIVER US FROM EVIL
# THE HELP
# THE DOUBLE COMFORT SAFARI CLUB
# THIS BODY OF DEATH
# LUCID INTERVALS
# THE SHADOW OF YOUR SMILE
# BURNING LAMP
# EVERY LAST ONE
# EIGHT DAYS TO LIVE
# CHANGES
# CAUGHT
# HOUSE RULES
# MATTERHORN
# THE WALK
# DECEPTION
# BEATRICE AND VIRGIL
# WRECKED
# SILVER BORNE
# ABRAHAM LINCOLN: VAMPIRE HUNTER
# A RIVER IN THE SKY

# %%
#mothers day in 2009
response = requests.get('http://api.nytimes.com/svc/books/v2/lists/2009-05-10/hardcover-fiction.json?api-key=3880684abea14d86b6280c6dbd80a793')
data = response.json()
#print(data)
book_result = data['results']

#print(book_result)

for i in book_result:
    #print(i['book_details'])
    for item in i['book_details']:
        print(item['title'])
# Out:
# FIRST FAMILY
# TEA TIME FOR THE TRADITIONALLY BUILT
# LOITERING WITH INTENT
# JUST TAKE MY HEART
# THE PERFECT POISON
# THE HOST
# LOOK AGAIN
# DEADLOCK
# LONG LOST
# TURN COAT
# THE ASSOCIATE
# HANDLE WITH CARE
# THE HELP
# THE GUERNSEY LITERARY AND POTATO PEEL PIE SOCIETY
# FATALLY FLAKY
# ARTHAS
# A RELIABLE WIFE
# BORDERLINE
# ONE SECOND AFTER
# BONEMAN'S DAUGHTERS

# %%
#fathers day in 2009
response = requests.get('http://api.nytimes.com/svc/books/v2/lists/2010-06-20/hardcover-fiction.json?api-key=3880684abea14d86b6280c6dbd80a793')
data = response.json()
#print(data)
book_result = data['results']

#print(book_result)

for i in book_result:
    #print(i['book_details'])
    for item in i['book_details']:
        print(item['title'])
# Out:
# THE GIRL WHO KICKED THE HORNET’S NEST
# BULLET
# THE SPY
# THE HELP
# DEAD IN THE FAMILY
# 61 HOURS
# THE BURNING WIRE
# STORM PREY
# THE BOURNE OBJECTIVE
# INNOCENT
# HEART OF THE MATTER
# THE 9TH JUDGMENT
# BLOCKADE BILLY
# ALLIES
# THE RULE OF NINE
# FEVER DREAM
# DELIVER US FROM EVIL
# MATTERHORN
# THE PARTICULAR SADNESS OF LEMON CAKE
# DANGEROUS

# %%
#fathers day in 2009
response = requests.get('http://api.nytimes.com/svc/books/v2/lists/2010-06-21/hardcover-fiction.json?api-key=3880684abea14d86b6280c6dbd80a793')
data = response.json()
#print(data)
book_result = data['results']

#print(book_result)

for i in book_result:
    #print(i['book_details'])
    for item in i['book_details']:
        print(item['title'])
# Out:
# THE GIRL WHO KICKED THE HORNET’S NEST
# THE LION
# THE PASSAGE
# THE HELP
# THE SPY
# DEAD IN THE FAMILY
# 61 HOURS
# BULLET
# STORM PREY
# INNOCENT
# HEART OF THE MATTER
# THE BURNING WIRE
# THE 9TH JUDGMENT
# THE BOURNE OBJECTIVE
# DEATH ECHO
# BLOCKADE BILLY
# DELIVER US FROM EVIL
# THE PARTICULAR SADNESS OF LEMON CAKE
# MATTERHORN
# FEVER DREAM
